# %%
import numpy as np
import pandas as pd
import torch
from torch.utils.data import DataLoader
from tqdm import tqdm

from habr_article_analyzer.data import DEFAULT_FULL_PATH, download_dataset
from habr_article_analyzer.data_loader import HabrDataset
from habr_article_analyzer.data_utils.split_dataset import split_dataset
from habr_article_analyzer.datasets.lazy_ranking import (
    FullLazyRankingDataset,
    SamplingLazyRankingDataset,
)
from habr_article_analyzer.metrics.ranking_metrics import RankingMetrics
from habr_article_analyzer.models.encoders.hub_averaging_encoder import HubEncoder
from habr_article_analyzer.models.encoders.tf_idf_encoder import TextEncoder
from habr_article_analyzer.models.predictors.ranking_nn import RankingModel
from habr_article_analyzer.settings import data_settings, settings
from habr_article_analyzer.targets import Target
from habr_article_analyzer.trainers.classification_trainer import Trainer

# %% [markdown]
# # Baseline
#
# *Author: Sergiy Iarygin*

# %% [markdown]
# The goal of this notebook is to prepare the baseline. Our task: predict the probability that given hub is a match for a given text. This is how the model will work:
#
# 1. We take two inputs: text and hub, which we need to map to some vectors. Model `A`, based on bag of words (Tf-Idf bag of words), will map text to some vector in $R^n$.
# 2. Then for each matched pair (text_i, hub_j) in dataset we aggregate `avg(A(text_i))` as an embedding of hub. Now `hub_j` embedding is ` avg(A(text_i))`.
# 3. Model `C` estimates the probability based on this two vectors: embed of text and embed of hub.
#
# As model `C` we will use classic DL with couple stacked layers.

# %%
download_dataset(DEFAULT_FULL_PATH)

# %%
split_dataset()

# %%
train_df = HabrDataset(
    path=settings.raw_data_dir / "train.jsonl.zst",
    batch_size=data_settings.batch_size,
).get_dataframe()
val_df = HabrDataset(
    path=settings.raw_data_dir / "val.jsonl.zst",
    batch_size=data_settings.batch_size,
).get_dataframe()
test_df = HabrDataset(
    path=settings.raw_data_dir / "test.jsonl.zst",
    batch_size=data_settings.batch_size,
).get_dataframe()
# Out:
# Reading dataset: 181226it [00:16, 10748.76it/s]
# Reading dataset: 60409it [00:05, 11276.74it/s]
# Reading dataset: 60408it [00:04, 13219.92it/s]

# %%
train_target = Target(train_df, "hubs", sparse=True)
val_target = Target(val_df, "hubs", sparse=True)

# %%
text_encoder = TextEncoder()
text_encoder.fit(train_df["text_markdown"])
text_encoder.save(settings.models_dir / "text_encoder.pt")
# Out:
# /home/sergiy/habr-article-analyzer/env/lib/python3.11/site-packages/sklearn/feature_extraction/text.py:402: UserWarning: Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens ['хотел'] not in stop_words.
#   warnings.warn(

# %%
text_embeddings_train = text_encoder.transform(train_df["text_markdown"])
text_embeddings_val = text_encoder.transform(val_df["text_markdown"])

# %%
hub_encoder = HubEncoder()
hub_encoder.fit(train_target, text_embeddings_train)
hub_encoder.save(settings.models_dir / "hub_encoder.pt")

# %%
hub_embeddings_train = hub_encoder.transform(train_target.labels)
hub_embeddings_val = hub_encoder.transform(val_target.labels)

# %%
sampled_dataset_train = SamplingLazyRankingDataset(
    text_embeddings_train,
    hub_embeddings_train,
    train_target,
    1,
    3,
    "label_proportional",
)
sampled_dataset_val = SamplingLazyRankingDataset(
    text_embeddings_val, hub_embeddings_val, val_target, 1, 3, "label_proportional"
)

# %%
model = RankingModel(input_dim=10000, hidden_dims=[512, 256, 128])

trainer = Trainer(
    model,
    device="cuda",
    log_dir=settings.raw_data_dir / "runs/experiment_2",
    train_dir=settings.raw_data_dir / "train",
)
# Out:
# TensorBoard logs will be saved to: /home/sergiy/habr-article-analyzer/data/raw/runs/experiment_2
# Run: tensorboard --logdir=/home/sergiy/habr-article-analyzer/data/raw/runs/experiment_2

# %%
history = trainer.fit(
    train_loader=DataLoader(
        sampled_dataset_train, batch_size=256, shuffle=True, drop_last=True
    ),
    val_loader=DataLoader(
        sampled_dataset_val, batch_size=256, shuffle=True, drop_last=True
    ),
    epochs=10,
    lr=0.001,
    weight_decay=0.0001,
    patience=2,
)
# Out:
# TRAINING START
# Epoch 1 [Train]: 100%|██████████| 2831/2831 [05:11<00:00,  9.09it/s, loss=0.2386]
# Epoch 1 [Val]: 100%|██████████| 943/943 [00:53<00:00, 17.77it/s]
# Epoch 1/10 Summary (Time: 365.6s)
# Train Loss: 0.2826 | Train AUC: 0.9308
# Val Loss:   0.2787 | Val AUC:   0.9328 |Val PR-AUC: {val_pr_auc:.4f}
# Learning Rate: 0.001000
# Best model saved. (AUC: 0.9328)
# Epoch 2 [Train]: 100%|██████████| 2831/2831 [05:08<00:00,  9.19it/s, loss=0.2834]
# Epoch 2 [Val]: 100%|██████████| 943/943 [00:51<00:00, 18.17it/s]
# Epoch 2/10 Summary (Time: 361.2s)
# Train Loss: 0.2665 | Train AUC: 0.9390
# Val Loss:   0.2721 | Val AUC:   0.9362 |Val PR-AUC: {val_pr_auc:.4f}
# Learning Rate: 0.001000
# Best model saved. (AUC: 0.9362)
# Epoch 3 [Train]: 100%|██████████| 2831/2831 [05:07<00:00,  9.20it/s, loss=0.2561]
# Epoch 3 [Val]: 100%|██████████| 943/943 [00:52<00:00, 17.89it/s]
# Epoch 3/10 Summary (Time: 361.5s)
# Train Loss: 0.2533 | Train AUC: 0.9452
# Val Loss:   0.2706 | Val AUC:   0.9373 |Val PR-AUC: {val_pr_auc:.4f}
# Learning Rate: 0.001000
# Best model saved. (AUC: 0.9373)
# Epoch 4 [Train]: 100%|██████████| 2831/2831 [05:08<00:00,  9.18it/s, loss=0.2244]
# Epoch 4 [Val]: 100%|██████████| 943/943 [00:52<00:00, 18.06it/s]
# Epoch 4/10 Summary (Time: 361.8s)
# Train Loss: 0.2437 | Train AUC: 0.9495
# Val Loss:   0.2680 | Val AUC:   0.9382 |Val PR-AUC: {val_pr_auc:.4f}
# Learning Rate: 0.001000
# Best model saved. (AUC: 0.9382)
# Epoch 5 [Train]: 100%|██████████| 2831/2831 [05:08<00:00,  9.18it/s, loss=0.2664]
# Epoch 5 [Val]: 100%|██████████| 943/943 [00:52<00:00, 17.92it/s]
# Epoch 5/10 Summary (Time: 362.1s)
# Train Loss: 0.2357 | Train AUC: 0.9529
# Val Loss:   0.2675 | Val AUC:   0.9388 |Val PR-AUC: {val_pr_auc:.4f}
# Learning Rate: 0.001000
# Best model saved. (AUC: 0.9388)
# Epoch 6 [Train]: 100%|██████████| 2831/2831 [05:07<00:00,  9.20it/s, loss=0.2420]
# Epoch 6 [Val]: 100%|██████████| 943/943 [00:51<00:00, 18.22it/s]
# Epoch 6/10 Summary (Time: 360.4s)
# Train Loss: 0.2302 | Train AUC: 0.9552
# Val Loss:   0.2686 | Val AUC:   0.9382 |Val PR-AUC: {val_pr_auc:.4f}
# Learning Rate: 0.001000
# No improvement for 1 epochs
# Epoch 7 [Train]: 100%|██████████| 2831/2831 [05:09<00:00,  9.15it/s, loss=0.2559]
# Epoch 7 [Val]: 100%|██████████| 943/943 [00:52<00:00, 17.83it/s]
# Epoch 7/10 Summary (Time: 363.5s)
# Train Loss: 0.2252 | Train AUC: 0.9572
# Val Loss:   0.2689 | Val AUC:   0.9386 |Val PR-AUC: {val_pr_auc:.4f}
# Learning Rate: 0.001000
# No improvement for 2 epochs
#
# Early stopping triggered after 7 epochswith no improvement
# TRAINING COMPLETE
# Total time: 42.3 minutes
# Best Val AUC: 0.9388
# View results: tensorboard --logdir=/home/sergiy/habr-article-analyzer/data/raw/runs/experiment_2

# %% [markdown]
# AUC looks impressive, while it does not guarantee anything on ranking task.

# %%
model = RankingModel(input_dim=10000)

# %%
model.load_state_dict(torch.load("best_model.pt"))
torch.save(model.state_dict(), settings.models_dir / "bow_dssm_1.pt")
model.to("cuda")
# Out:
# RankingModel(
#   (model): Sequential(
#     (0): Linear(in_features=10000, out_features=512, bias=True)
#     (1): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Dropout(p=0.1, inplace=False)
#     (4): Linear(in_features=512, out_features=256, bias=True)
#     (5): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU()
#     (7): Dropout(p=0.1, inplace=False)
#     (8): Linear(in_features=256, out_features=128, bias=True)
#     (9): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (10): ReLU()
#     (11): Dropout(p=0.1, inplace=False)
#     (12): Linear(in_features=128, out_features=1, bias=True)
#     (13): Sigmoid()
#   )
# )

# %%
text_encoder = TextEncoder(max_features=5000).load(
    settings.models_dir / "text_encoder.pt"
)
hub_encoder = HubEncoder(dim=5000).load(settings.models_dir / "hub_encoder.pt")

# %%
test_df = (
    HabrDataset(
        path=settings.raw_data_dir / "test.jsonl.zst",
        batch_size=data_settings.batch_size,
    )
    .get_dataframe()
    .sample(500)
)
# Out:
# Reading dataset: 60408it [00:04, 13633.68it/s]

# %%
test_df.head()
# Out:
#            id                                      text_markdown  \
# 45884  285760  Я руководитель небольшой дизайн-студии. Расска...
# 60248  364979  > «А тот, который во мне сидит,\n>  Считает, ч...
# 49321  201448  На днях стало известно о том, что компания ID ...
# 54135  116290  Сообщество жизненно важно любому проекту Open ...
# 17629  668160  Привет, Хабр! Меня зовут Сергей Петровский, я ...
#
#                                                   hubs
# 45884                           [sales, business-laws]
# 60248  [gadgets, popular_science, multicopters, games]
# 49321                                          [linux]
# 54135                                    [open_source]
# 17629                      [sberbank, it_testing, dwh]

# %%
text_embeddings_test = text_encoder.transform(test_df["text_markdown"])
test_target = Target(test_df, "hubs", sparse=True)
hub_embeddings_test = hub_encoder.transform(test_target.labels)
# Out:
# /home/sergiy/habr-article-analyzer/env/lib/python3.11/site-packages/sklearn/feature_extraction/text.py:402: UserWarning: Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens ['хотел'] not in stop_words.
#   warnings.warn(

# %%
full_dataset_test = FullLazyRankingDataset(
    text_embeddings_test, hub_embeddings_test, test_target
)

# %%
predicts = []
loader = DataLoader(full_dataset_test, batch_size=256, shuffle=False)


with torch.no_grad():
    for features, labels in tqdm(loader, desc="applying model to test dataset"):
        gpu_features = features.to("cuda")
        gpu_predicts = model(gpu_features)
        for predict in gpu_predicts.to("cpu"):
            predicts.append(predict.item())
# Out:
# applying model to test dataset: 100%|██████████| 674/674 [00:25<00:00, 26.47it/s]

# %%
predicts = np.reshape(
    np.array(predicts), shape=(len(text_embeddings_test), len(hub_embeddings_test))
)

# %% [markdown]
# Let's see the predicted ranking:

# %%
for j, sorted_targets in enumerate(predicts.argsort(axis=1)[:, ::-1]):
    print(test_df.iloc[j]["text_markdown"][:100])
    print(test_df.iloc[j]["hubs"])
    print([test_target.labels[i] for i in sorted_targets[:10]])
# Out:
# Я руководитель небольшой дизайн-студии. Расскажу о некоторых признаках договорных тендеров.
# К сожале
# ['sales', 'business-laws']
# ['saas', 'nanosoft', 'desktop_environment', 'i_am_advertising', 'google', 'scrumtrek', 'epam_systems', 'kelnik', 'cad_cam', 'itsumma']
# > «А тот, который во мне сидит,
# >  Считает, что он — истребитель.» (с) Высоцкий
# >
# Подарок защитникам
# ['gadgets', 'popular_science', 'multicopters', 'games']
# ['google', 'desktop_environment', 'dell_technologies', 'paysto', 'google_chrome', 'tuturu', 'service_desk', 'telebreeze', 'bigdata', 'itsumma']
# На днях стало известно о том, что компания ID Software отказывается от поддержки Mac OS X и Linux дл
# ['linux']
# ['google', 'i_am_advertising', 'erp', 'css', 'kelnik', 'browsers', 'code_wtf', 'desktop_environment', 'crazydev', 'nanosoft']
# Сообщество жизненно важно любому проекту Open Source. Активное и живое сообщество явлется сердцем пр
# ['open_source']
# ['unity', 'nanosoft', 'desktop_environment', 'epam_systems', 'uprock', 'erp', 'i_am_advertising', 'google', 'office', 'infographics']
# Привет, Хабр! Меня зовут Сергей Петровский, я руководитель IT-направления в СберТехе — компании, кот
# ['sberbank', 'it_testing', 'dwh']
# ['helpdesk', 'erp', 'cloud_services', 'cloud_computing', 'nanosoft', 'dataline', 'office', 'bigdata', 'glowbyte', 'billing']
# Добрый день,
# Данный топик я публикую по мотивам топика Программирование в PHP для командной строки,
# ['webdev']
# ['desktop_environment', 'i_am_advertising', 'nanosoft', 'video', 'erp', 'google', 'timeweb', 'epam_systems', 'patents', 'itsumma']
# Сегодня я хочу представить вашему вниманию подробный пользовательский обзор смартфона Google Pixel 6
# ['smartphones']
# ['wirenboard', 'thirdpin', 'ua-hosting', 'prolan', 'ui', 'desktop_environment', 'vk', 'usability', 'synesis', 'home_automation']
# После заявления Джобса, Microsoft не скупилась на словах и комментариях, в которых промелькнуло неск
# ['itcompanies']
# ['closet', 'drupal', 'code_wtf', 'greasemonkey', 'browsers', 'firefox', 'google', 'google_chrome', 'doctrine', 'facebook_api']
# ### Истоки и причины
# В свободное время мне иногда очень приятно покопаться в какой-нибудь старой опе
# ['soft']
# ['i_am_advertising', 'desktop_environment', 'google', 'nanosoft', 'epam_systems', 'virtualization', 'crowdsourcing', 'win_dev', 'crm', 'timeweb']
# На Indiegogo начался сбор средств на самый дорогой проект в истории краудфандинга: постройку реплики
# ['crowdsourcing']
# ['i_am_advertising', 'webdev', 'pay_system', 'kelnik', 'r', 'wireless', 'desktop_environment', 'video', 'office', 'google']
# И.о. президента Российской ассоциации эксплуатантов воздушного транспорта (АЭВТ, объединяет «Аэрофло
# ['business-laws', 'career', 'transport']
# ['desktop_environment', 'cad_cam', 'office', 'dell_technologies', 'cloud_computing', 'cloud_services', 'biotech', 'DIY', 'pm', 'remote']
# Китайская компания ADATA, владеющая игровым брендом XPG, разработала прототипы сверхбыстрых твердоте
# ['dwh', 'data_warehouse', 'hardware']
# ['usabilitylab', 'desktop_environment', 'i_am_advertising', 'nanosoft', 'history', 'google', 'hi', 'epam_systems', 'infographics', 'cloud_computing']
# Не поверил демонстрации возможностей Ublox GNSS модуля ZED-F9P.
# Решил самостоятельно оценить точност
# ['netdev', 'robo_dev', 'controllers', 'robot']
# ['office', 'DIY', 'wirenboard', 'telebreeze', 'google', 'android_dev', 'nanosoft', 'desktop_environment', 'thirdpin', 'synesis']
# Всем привет! Меня зовут Лихопой Кирилл и я - фуллстак-разработчик. Сегодня я представляю вам перевод
# ['css', 'html5']
# ['closet', 'i_am_advertising', 'browsers', 'nerepetitor', 'cms', 'google', 'usabilitylab', 'drupal', 'desktop_environment', 'browser_extensions']
# В MediaWiki, начиная с версии 1.17, появился новый механизм сборки и загрузки стилей и скриптов — Re
# ['crowdsourcing']
# ['android_dev', 'i_am_advertising', 'agile', 'google', 'desktop_environment', 'kelnik', 'crm', 'crowdsourcing', 'epam_systems', 'hi']
# На прошлой неделе, 19—23 мая, в Барселоне проходила главная европейская конференция по Kubernetes и
# ['flant', 'open_source', 'tech_events', 'kubernetes']
# ['tech_events', 'cloud_computing', 'southbridge', 'sbercloud', 'virtualization', 'saas', 'service_desk', 'hackathons', 'parallels', 'history']
# МКС видна чуть правее центра Луны. Фото: Bill Ingalls / NASA
# Фотографы-любители часто делают фотогра
# ['popular_science', 'photo', 'space']
# ['astronomy', 'DIY', 'energy', 'i_am_advertising', 'patents', 'google', 'paysto', '3d-printers', 'nanosoft', 'easyelectronics']
# Привет, Хабр! Unity 5 предоставляет нам из коробки систему глобального освещения (Global Illuminatio
# ['programming', 'gamedev', 'unity']
# ['desktop_environment', 'i_am_advertising', 'nanosoft', 'google', 'crm', 'infographics', 'kelnik', 'epam_systems', 'itsumma', 'hi']
# Как вы разрабатываете веб-приложение на Java?
# После каждого изменения, как вы его запускаете и прове
# ['webdev', 'java']
# ['java', 'mobile_dev', 'hackathons', 'synesis', 'i_am_advertising', 'google', 'otus', 'video', 'cloud_computing', 'epam_systems']
# В процессе создания контейнеров ключевым компонентом является изоляция процессов. При этом одним из
# ['ruvds', 'linux', 'sys_admin', 'nix', 'linux_dev']
# ['dcmiran', 'i_am_advertising', 'desktops', 'alexhost', 'drupal', 'closet', 'browsers', '1cloud', 'hi', 'cms']
# Доброго времени суток. Эта статья не откроет Вам новые грани программирования, она не расскажет о кл
# ['gamedev', 'csharp']
# ['i_am_advertising', 'desktop_environment', 'vuejs', 'webdev', 'vs', 'yii', 'nanosoft', 'google', 'typescript', 'win_dev']
# Phase Four сообщает о запуске спутников, оснащенных плазменными двигателями компании. В Phase Four з
# ['space']
# ['nanosoft', 'energy', 'croc', 'autogadgets', 'google', 'telebreeze', 'video_conferencing', 'futurenow', 'finance', 'erp']
# Приветствую, %username%. Сегодня разработаем скрипт составления рейтинга схожести интересов между лю
# ['python', 'data_mining', 'algorithms', 'maths']
# ['i_am_advertising', 'google', 'crazydev', 'csharp', 'nanosoft', 'itsumma', 'history', 'hi', 'kelnik', 'debug']
# Большинство сайтов переполнены мелким текстом, который больно читать. Почему? Нет никаких причин для
# ['closet']
# ['usability', 'ui', 'desktop_environment', 'i_am_advertising', 'google', 'weban', 'usabilitylab', 'io', 'sales', 'web_design']
# В предыдущем топике я обещал подробнее описать особенности программирования промышленных PLC, и поче
# ['intel', 'crazydev', 'compilers']
# ['scala', 'programming', 'controllers', 'zadachki', 'csharp', 'net', 'compilers', 'sport_programming', 'dcmiran', 'hi']
# В этой статье мы поговорим о извлечение значений подписи `ECDSA R, S, Z` из блокчейна Биткойн, но дл
# ['crypto', 'iot_dev', 'lifehacks', 'cryptocurrency', 'futurenow']
# ['i_am_advertising', 'google', 'crypto', 'desktop_environment', 'dataline', 'nanosoft', 'timeweb', 'epam_systems', 'erp', 'itsumma']
# Проанализировав блоги многих людей, занимающихся интернет бизнесом, я выявил несколько методов, кото
# ['closet']
# ['i_am_advertising', 'weban', 'hi', 'desktop_environment', 'study', 'facebook_api', 'sberbank', 'google', 'erp', 'epam_systems']
# Регулятор ЕС не планирует обжаловать решение суда об отмене штрафа в размере €997 млн, назначенного
# ['business-laws', 'finance', 'itcompanies']
# ['cpu', 'intel', 'itcompanies', 'desktops', 'soft', 'dcmiran', 'usabilitylab', 'video_conferencing', 'gadgets', 'mobileanalytics']
# # Разработка игр
# Кто не мечтал попробывать разработать собственную игру. Мы будем создавать игру в с
# ['crazydev']
# ['erp', 'nanosoft', 'desktop_environment', 'google', 'epam_systems', 'i_am_advertising', 'kelnik', 'timeweb', 'itsumma', 'video']
# Хотелось бы поговорить с хабросообществом на тему того, кто и как, проводит большую часть своей жизн
# ['closet']
# ['nanosoft', 'desktop_environment', 'cloud_services', 'google', 'research', 'browsers', 'i_am_advertising', 'remote', 'productivity_inside', 'cad_cam']
# Совсем недавно возникла задача создания программного обеспечения по генерации картографических тайло
# ['openstreetmap']
# ['nanosoft', 'cms', 'django', 'video', 'ctf', 'api', 'i_am_advertising', 'itsumma', 'patents', 'timeweb']
# Есть в моем ведении несколько VPSов, на которых крутится... вообщем не моя зона ответственности, и п
# ['nginx']
# ['i_am_advertising', 'nanosoft', 'desktop_environment', 'google', 'vuejs', 'timeweb', 'kelnik', 'epam_systems', 'itsumma', 'hi']
# Специалисты по безопасности из Context Information Security продемонстрировали, как можно взломать о
# ['infosecurity']
# ['prolan', 'i_am_advertising', 'twitter_api', 'service_desk', 'google', 'synesis', 'paysto', 'pt', 'desktop_environment', 'crowdsourcing']
# Приходилось ли вам когда-нибудь развёртывать профессиональную коммерческую систему мониторинга или A
# ['prolan']
# ['code_wtf', 'i_am_advertising', 'crazydev', 'desktop_environment', 'css', 'magento', 'javascript', 'webdev', 'open_source', 'vuejs']
# Первый полет и посадка вертолета «Индженьюити» официально зарегистрированы в Международной организац
# ['popular_science', 'space', 'multicopters', 'futurenow']
# ['yii', 'i_am_advertising', 'google', 'desktop_environment', 'wp_dev', '1cloud', 'hi', 'open_source', 'epam_systems', 'crm']
# Сегодня все большую популярность приобретают минимализм и аскетичные тенденции в дизайне интерьера.
# ['pult', 'popular_science', 'Peripheral', 'sound']
# ['sound', 'typography', 'office', 'synesis', 'timeweb', 'i_am_advertising', 'popular_science', 'autogadgets', 'desktop_environment', 'DIY']
# ##### Вступление
# Тема весьма избитая, уж что только нам не предлагают всяческие обменники и оператор
# ['pay_system']
# ['cloud_services', 'android_dev', 'patents', 'api', 'business_models', 'geo', 'ecommerce_development', 'epam_systems', 'google', 'ctf']
# Уже несколько лет мы выпускаем бесплатный журнал VR-Online для начинающих программистов и всех тех,
# ['i_am_advertising']
# ['desktop_environment', 'i_am_advertising', 'google', 'kelnik', 'erp', 'nanosoft', 'crowdsourcing', 'epam_systems', 'itsumma', 'webdev']
# Я старый автомобилист, и не знаю слов любви к производителям навигационных программ. У меня давнее о
# ['autogadgets']
# ['telebreeze', 'wireless', 'videocards', 'video', 'synesis', 'multicopters', 'transport', 'android_dev', 'energy', 'google']
# Приветствую уважаемых читателей.
# Как и обещал в первой статье Быстрая разработка CRUD на Java: даунш
# ['open_source', 'java', 'code_wtf']
# ['deliveryclub', 'auriga', 'analysis_design', 'epam_systems', 'i_am_advertising', 'ecommerce_development', 'dell_technologies', 'soft', 'erp', 'cloud_computing']
# > Я давно лелеял мечту изучать лингвистику в Кембриджском университете. Каждое лето он проводит сред
# ['timeweb', 'popular_science', 'learning_languages']
# ['spbifmo', 'nanosoft', 'desktop_environment', 'i_am_advertising', 'study', 'open_source', 'google', 'kelnik', 'wunderfund', 'epam_systems']
# Не уверен, что это можно отнести к теме «работа со звуком», но более подходящего блога я не нашел.
# П
# ['sound']
# ['win_dev', 'wp_dev', 'yii', 'nanosoft', 'desktop_environment', 'hi', 'cloud_computing', 'opera', 'zadachki', 'browsers']
# Автор статьи – Фредерик Филю (Frédéric Filloux) – генеральный управляющий французского консорциума э
# ['media_management']
# ['ecommerce', 'contentmarketing', 'business_models', 'cryptocurrency', 'data_mining', 'display_adv', 'conpay', 'artificial_intelligence', 'crowdsourcing', 'i_am_advertising']
# В феврале этого года Magento сделала свой курс «Fundamentals of Magento development» бесплатным. Он
# ['php']
# ['i_am_advertising', 'hi', 'wp_dev', 'nanosoft', 'google', 'win_dev', 'desktop_environment', 'machine_learning', 'crowdsourcing', 'cloud_computing']
# Тенденции последних лет свидетельствуют о борьбе властей разных стран мира с наличными деньгами. Све
# ['payonline', 'infographics', 'finance']
# ['cryptocurrency', 'pay_system', 'patents', 'payonline', 'crowdsourcing', 'i_am_advertising', 'history', 'it_bigraphy', 'prolan', 'research']
# Эти два графа являются изоморфными
# Математик Ласло Бабай (László Babai) с факультета компьютерных на
# ['zadachki', 'maths']
# ['android_dev', 'crazydev', 'desktop_environment', 'i_am_advertising', 'css', 'data_warehouse', 'history', 'google', 'nanosoft', 'usabilitylab']
# Отличная весть для всех использующих дополнительные скрипты и стили, наработанные за последние год-д
# ['habr']
# ['nanosoft', 'desktop_environment', 'typography', 'google', 'i_am_advertising', 'crm', 'crowdsourcing', 'epam_systems', 'helpdesk', 'itsumma']
# Пост ориентирован на новичков. В нем не рассматривается настройка Visual Studio. Он научит вас настр
# ['programming']
# ['cloud_computing', 'data_warehouse', 'dataline', 'fujitsu', 'nanosoft', 'net', 'galtsystems', 'desktop_environment', 'hi', 'data_mining']
# 18 декабря стартовал отборочный тур для участия в хакатоне DeepHack.Babel от Лаборатории нейронных с
# ['mipt', 'hackathons', 'machine_learning']
# ['i_am_advertising', 'data_mining', 'artificial_intelligence', 'google', 'erp', 'usabilitylab', 'epam_systems', 'kelnik', 'office', 'biotech']
# Из Австралии поступает неприятная новость (на Slashdot её выложили, а блоггер lqp перевёл). Оказывае
# ['business-laws']
# ['usabilitylab', 'desktop_environment', 'i_am_advertising', 'typography', 'webdev', 'ui', 'google', 'closet', 'crowdsourcing', 'hi']
# Правительство РФ приняло решение внести изменения в правила формирования и ведения Единого реестра р
# ['business-laws', 'soft']
# ['cloud_computing', 'fujitsu', 'dell_technologies', 'dcmiran', 'cloud_services', 'croc', 'hi', 'nanosoft', 'erp', 'southbridge']
# Мединский и Михалков, партнёры по налогу на интернет
# Фото: Александр Шалгин / Пресс-служба Госдумы Р
# ['copyright']
# ['desktop_environment', 'google', 'i_am_advertising', 'epam_systems', 'nanosoft', 'erp', 'timeweb', 'itsumma', 'hi', 'helpdesk']
# ## Начало
# Джуд Мансилла (Jude Mansilla), основатель форума Head-Fi, 12.05.2009.
# В нашем торгово-спон
# ['sound']
# ['desktop_environment', 'i_am_advertising', 'telebreeze', 'thirdpin', 'erp', 'nanosoft', 'hi', 'google', 'nerepetitor', 'history']
# Представляем интервью с ведущими экспертами в области безопасности: Владимиром Кочетковым (руководит
# ['jugru', 'infosecurity', 'net']
# ['android_dev', 'api', 'angular', 'desktop_environment', 'win_dev', 'broadcast', 'nanosoft', 'google', 'hi', 'vuejs']
# Кратко для введения: я являюсь профессиональным разработчиком игр и мне есть что сказать себе 15 лет
# ['programming', 'study', 'career']
# ['desktop_environment', 'i_am_advertising', 'google', 'kelnik', 'crowdsourcing', 'nanosoft', 'hi', 'erp', 'it_bigraphy', 'timeweb']
# В прошлой статье меня упрекнули, что я при живом Vue 3 пишу про "устаревший" Vue 2. Отговорившись те
# ['webdev', 'javascript', 'itstandarts', 'vuejs', 'typescript']
# ['system_programming', 'programming', 'desktop_environment', 'server_side_optimization', 'scada', 's_admin', 'selectel', 'reactjs', 'sport_programming', 'webdev']
# Юрист «Рустам Курмаев и партнёры» Дмитрий Горбунов в интервью «Известиям» рассказал об использовании
# ['business-laws', 'social_networks', 'itcompanies']
# ['design', 'i_am_advertising', 'crowdsourcing', 'web_design', 'display_adv', 'context', 'usabilitylab', 'contentmarketing', 'cad_cam', 'paysto']
# Индийский филиал Sony Pictures направил Google требование удалить 34 URL-адреса с платформы Sony Liv
# ['copyright', 'itcompanies']
# ['google', 'video_conferencing', 'i_am_advertising', 'desktop_environment', 'erp', 'video_tech', 'dell_technologies', 'arduino', 'crowdsourcing', 'yii']
# В подкасте речь пойдет главным образом о возможном выпуске таблетки от Apple — Mactouch.
# — Сенсация,
# ['closet']
# ['paysto', 'synesis', 'weban', 'uipath', 'i_am_advertising', 'usabilitylab', 'ui', 'web_design', 'hi', 'stc_spb']
# > Для будущих учащихся на курсе "Kotlin Backend Developer" подготовили перевод материала.
# >
# > Также
# ['otus', 'programming', 'kotlin']
# ['java', 'epam_systems', 'csharp', 'billing', 'google', 'android_dev', 'cloud_computing', 'southbridge', 'desktop_environment', 'net']
# В написании научных статей немалую часть времени занимает подготовка иллюстраций, графиков и диаграм
# ['programming', 'maths', 'matlab']
# ['i_am_advertising', 'nanosoft', 'google', 'desktop_environment', 'epam_systems', 'itsumma', 'timeweb', 'hi', 'infographics', 'crm']
# Сегодня начиная с раннего утра множество пользователей испытывает проблемы с подключением ICQ клиент
# ['closet']
# ['i_am_advertising', 'google', 'southbridge', 'epam_systems', 'otus', 'scala', 'r', 'sportmaster_lab', 'zadachki', 'net']
# Добро пожаловать на летний Яндекс.Субботник.
# Мы заранее подготовили и выложили для вас презентации д
# ['yandex']
# ['nanosoft', 'ui', 'i_am_advertising', 'google', 'design', 'office', 'crowdsourcing', 'hflabs', 'kelnik', 'telebreeze']
# Визулизация данных социальной сети:
# Два больших постера (200см x 90см) показывают особенности и взаи
# ['closet']
# ['desktop_environment', 'i_am_advertising', 'google', 'cloud_computing', 'video_conferencing', 'nanosoft', 'hi', 'crowdsourcing', 'epam_systems', 'first']
# Два месяца назад 20-летний студент из Казахстана, испытав на себе все прелести нашего высшего образо
# ['i_am_advertising']
# ['usabilitylab', 'typography', 'kelnik', 'cad_cam', 'desktop_environment', 'nanosoft', 'erp', 'video', 'crm', 'patents']
# ##### Динамическое отображение логов в броузере на Node.js & WebSocket
# Иногда возникает потребность
# ['nodejs']
# ['analysis_design', 'dell_technologies', 'billing', 'ecm', 'docsvision', 'epam_systems', 'angular', 'dwh', 'cloud_computing', 'django']
# Наиболее важное, о чём надо помнить, разрабатывая мобильное приложение, это то, что оно должно быть
# ['analysis_design', 'desktop_environment', 'mobile_dev', 'mobile_testing']
# ['i_am_advertising', 'desktop_environment', 'erp', 'google', 'epam_systems', 'cloud_computing', 'paysto', 'kelnik', 'hi', 'net']
# Перевод статьи «Building robust web apps with React: Part 1, in-browser prototypes», Matt Hinchliffe
# ['webdev', 'javascript', 'reactjs']
# ['reactjs', 'webdev', 'ui', 'javascript', 'nanosoft', 'usability', 'crazydev', 'localization', 'controllers', 'go']
# MySpace и Google выпустили пресс-релиз, который подтвердил слухи, что социальная сеть, принадлежащая
# ['itcompanies']
# ['i_am_advertising', 'business-laws', 'usabilitylab', 'google', 'epam_systems', 'droider', 'hi', 'video', 'crowdsourcing', 'kelnik']
# На моей первой работе в роли программиста у меня ушло три недели на то, чтобы полностью настроить ра
# ['infopulse', 'dev_management', 'pm', 'hr_management', 'career']
# ['yii', 'desktop_environment', 'uprock', 'webdev', 'google', 'i_am_advertising', 'vim', 'tech_events', 'vuejs', 'kelnik']
# Видя взмывающую в небеса ракету с космонавтами на борту, начинаешь думать о том, как люди становятся
# ['space']
# ['popular_science', 'telebreeze', 'urban', 'transport', 'space', 'tuturu', 'spbifmo', 'madrobots', 'image_processing', 'multicopters']
# #### Дано
#   1. Одна маленькая, но очень полезная библиотека. Включает в себя общую функциональность
# ['net']
# ['i_am_advertising', 'google', 'cloud_computing', 'hi', 'css', 'kelnik', 'erp', 'usabilitylab', 'nanosoft', 'cms']
# Интересно, посетители хабра часто используют «горячие клавиши»?
# Компания Microsoft, откровенно «приу
# ['closet']
# ['vs', 'saas', 'wp_dev', 'desktop_environment', 'i_am_advertising', 'nanosoft', 'google', 'win_dev', 'localization', 'cloud_computing']
# Изобретатель знаменитой логической игрушки в виде кубика венгерский скульптор и профессор архитектур
# ['zadachki']
# ['history', 'DIY', 'desktop_environment', 'multicopters', 'energy', 'medgadgets', 'crowdsourcing', 'madrobots', 'cyberpunk', 'futurenow']
# Мною было неоднократно замечено что хабрапользователи интересуются музыкальным софтом под nix-систем
# ['sound']
# ['google', 'browsers', 'erp', 'i_am_advertising', 'csharp', 'usabilitylab', 'vector_graphics', 'desktop_environment', 'nanosoft', 'vk']
# Придумал отличный сценарий для фильма, под условным название "Умный дом спешит на помощь".В завязке,
# ['popular_science', 'home_automation', 'sci-fi']
# ['remote', 'service_desk', 'nanosoft', 'cad_cam', 'i_am_advertising', 'desktop_environment', 'crm', 'google', 'erp', 'research']
# Носимая электроника — сфера, которая только начинает качественно изменяться. На днях немецкая компан
# ['medgadgets', 'gadgets', 'wearable_electronics', 'health']
# ['i_am_advertising', 'google', 'crazydev', 'crowdsourcing', 'csharp', 'geo', 'api', 'code_wtf', 'design', 'css']
# Хотел бы с Вами поделиться опытом создания своей первой мобильной игры. Весной 2012 года глядя на ар
# ['gamedev', 'android_dev', 'unity']
# ['1cloud', 'i_am_advertising', 'google', 'career', 'desktop_environment', 'crowdsourcing', 'epam_systems', 'community_management', 'agile', 'nanosoft']
# На собеседованиях собеседователи любят задавать всякие каверзные вопросы. Одним из любимых вопросов
# ['net']
# ['php', 'webdev', 'cloud_services', 'vk_api', 'usabilitylab', 'cloud_computing', 'yii', 'vuejs', 'i_am_advertising', 'zend_framework']
# > Как играть на на фортепиано? Все просто — в нужные моменты времени нажимать правильные клавиши!
# ##
# ['billing', 'electronics', 'cellular', 'itcompanies']
# ['easyelectronics', 'engineering_systems', 'nanosoft', 'antikvariat', 'energy', 'electronics', 'autogadgets', 'geo_systems', 'i_am_advertising', 'DIY']
# Приветствуем наших уважаемых читателей на страницах блога iCover! Не будет преувеличением сказать, ч
# ['icover', 'gadgets', 'hardware', 'smartphones']
# ['desktop_environment', 'i_am_advertising', 'google', 'wireless', 'epam_systems', 'crowdsourcing', 'itsumma', 'kelnik', 'nanosoft', 'hi']
# В этой подборке вы найдете много красивых и интерактивных сайтов, а также коллекцию уникальных интер
# ['uprock', 'web_design']
# ['webdev', 'web_design', 'ui', 'i_am_advertising', 'desktop_environment', 'django', 'javascript', 'usabilitylab', 'html5', 'css']
# Для начала нужно обзавестись этим самым "mesh"-ем поверхности, или триангуляцией поверхности, полиго
# ['python', 'cad_cam', 'maths']
# ['dwh', 'crypto', 'geo_systems', 'cisconetworks', 'data_warehouse', 'dataline', 'i_am_advertising', 'fujitsu', 'first', 'cloud_mts']
# Думаю многие ветераны интернета уже знакомы с этим рассказом, но все же хотелось бы познакомить с ни
# ['closet']
# ['desktop_environment', 'i_am_advertising', 'hi', 'google', 'vector_graphics', 'r', 'crowdsourcing', 'erp', 'epam_systems', 'web_design']
# В интернете участились случаи вымогательства с использованием дипфейк-видео. Преступники записывают
# ['business-laws', 'social_networks']
# ['prolan', 'pay_system', 'synesis', 'network_standarts', 'desktop_environment', 'payonline', 'saas', 'network_hardware', 'comptek', 'industrial_control_system']
# Приветствую всех Хабровчан!
# Представьте ситуацию, что в один прекрасный момент ваш жесткий диск/флеш
# ['acelab']
# ['cloud_services', 'office', 'algorithms', 'wp_dev', 'i_am_advertising', 'soft', 'DIY', 'desktop_environment', 'usabilitylab', 'yii']
# ## 5 - Convolutional Sequence to Sequence Learning
# В этом разделе мы будем реализовывать модель из с
# ['python', 'machine_learning']
# ['desktop_environment', 'nanosoft', 'google', 'i_am_advertising', 'hi', 'closet', 'cloud_computing', 'erp', 'crowdsourcing', 'geo']
# Любой проект, связанный с интернет-продвижением (включая разработку сайта) по умолчанию подвержен ри
# ['kelnik']
# ['paysto', 'crm', 'prolan', 'web_design', 'cloud_services', 'erp', 'technical_writing', 'service_desk', 'saas', 'google_chrome']
# Сегодня компания AMD согласовала с правительством Абу-Даби план инвестиций в размере 8.4 миллиардов
# ['closet']
# ['dcmiran', 'dell_technologies', 'i_am_advertising', 'nanosoft', 'csharp', 'desktop_environment', 'google', 'droider', 'helpdesk', 'win_dev']
# Скафандр Z-1
# 21 июля 1969 год. Заголовок газеты New York Times: «Люди гуляют по Луне!»
# Могли бы Нил
# ['telebreeze']
# ['i_am_advertising', 'desktop_environment', 'nanosoft', 'google', 'epam_systems', 'croc', 'kelnik', 'timeweb', 'cloud_mts', 'infographics']
# Пользователь Василий обращается в техподдержку «Не выделяется номер при регистрации документа ошибка
# ['docsvision', 'helpdesk', 'ecm', 'service_desk']
# ['i_am_advertising', 'kelnik', 'read', 'google', 'paysto', 'nanosoft', 'saas', 'nerepetitor', 'cloud_services', 'cloud_computing']
# vGate Compliance Checker — это бесплатная утилита разработки компании «Код Безопасности», позволяюще
# ['infosecurity']
# ['i_am_advertising', 'hi', 'vector_graphics', 'alexhost', 'google', 'office', 'cloud_services', 'epam_systems', 'doctrine', 'video']
# Вы часто пишете чиновникам письма? А часто они вам отвечают? Нравится ли вам то, что они отвечают? П
# ['analysis_design', 'ecm', 'productpm']
# ['desktop_environment', 'i_am_advertising', 'google', 'typography', 'epam_systems', 'erp', 'crowdsourcing', 'hi', 'itsumma', 'geo']
# Уже больше 10 лет существуют и появляются разного рода профессиональные системы для подбора персонал
# ['research']
# ['fujitsu', 'yii', 'i_am_advertising', 'wp_dev', 'hi', 'galtsystems', 'soft', 'erp', 'dell_technologies', 'geo']
# Как же глупы мнения некоторых людей из Ост-Индии, полагающих, что обезьяны и бабуины, которых там ог
# ['dev_management', 'hr_management', 'career', 'read', 'itcompanies']
# ['google', 'i_am_advertising', 'antikvariat', 'audiomania', 'history', 'kelnik', 'itsumma', 'timeweb', 'biotech', 'epam_systems']
# Как известно, Drupal является примером крайне тяжелой CMS/CMF, и нагруженные сайты строить на нем не
# ['drupal']
# ['sport_programming', 'vk', 'study', 'typescript', 'nanosoft', 'vs', 'i_am_advertising', 'tech_events', 'vuejs', 'desktop_environment']
# Японский дизайнер Yuri Suzuki сделал работоспособное радио в виде схемы Лондонского метрополитена:
# К
# ['electronics', 'hardware']
# ['gadgets', 'crowdsourcing', 'i_am_advertising', 'home_automation', 'stc_spb', 'DIY', 'design', 'infographics', 'video', 'network_hardware']
# Заменяем диспетчер задач
# Управляем автозагрузкой и следим за состоянием системы
# Устанавливаем перекл
# ['soft']
# ['desktop_environment', 'nanosoft', 'google', 'i_am_advertising', 'usabilitylab', 'vector_graphics', 'timeweb', 'vk', 'video', 'itsumma']
# Наш небольшой китайский заводик по производству спичечных коробков, расположенный в провинции Анхуэй
# ['habr']
# ['typography', 'usabilitylab', 'statistics', 'nanosoft', 'research', 'zadachki', 'desktop_environment', 'i_am_advertising', 'google', 'hi']
# Microsoft уже давно проявляет заметную активность в сфере Интернета вещей: Специализированные облачн
# ['internet_of_things', 'itcompanies']
# ['webdev', 'javascript', 'vuejs', 'erp', 'stc_spb', 'python', 'epam_systems', 'inDrive', 'programming', 'docsvision']
# Вместе с началом осени приближается Dell EMC Forum 2017 – одно из самых важных мероприятий компании,
# ['dell_technologies', 'it-infrastructure', 'network_technologies']
# ['i_am_advertising', 'desktop_environment', 'cloud_services', 'google', 'nanosoft', 'erp', 'cloud_mts', 'hi', 'epam_systems', 'business_models']
# Осенью 2016 года в Plarium Krasnodar появилась необходимость сформировать два новых отдела: 3D Anima
# ['plarium', '3d_graphics', 'bigdata']
# ['remote', 'study', 'i_am_advertising', 'pm', 'sport_programming', 'vk', 'tech_events', 'saas', 'kelnik', 'productpm']
# Верховный суд Великобритании постановил, что водители Uber — наёмные работники, а не самозанятые под
# ['community_management', 'business-laws', 'business_models', 'transport', 'itcompanies']
# ['desktop_environment', 'i_am_advertising', 'office', 'usabilitylab', 'controllers', 'gadgets', 'google_chrome', 'patents', 'dell_technologies', 'research']
# #### Задача
# Нужно написать настоящий сервис на эрланге, который будет работать в кластере. Кроме тог
# ['erlang']
# ['i_am_advertising', 'desktop_environment', 'zadachki', 'hi', 'google', 'saas', 'alexhost', 'algorithms', 'history', 'DIY']
# Пока одни отзывают свои модели, а другие пополняют линейку, мы подготовили для вас небольшую подборк
# ['medgadgets', 'gadgets', 'wearable_electronics']
# ['nanosoft', 'i_am_advertising', 'google', 'android_dev', 'tablets', 'office', 'epam_systems', 'cloud_services', 'video', 'geo']
# Задумал я как-то написать игру. Причем, по-быстрому. Желательно за неделю при условии работы на полс
# ['gamedev', 'android_dev', 'haxe']
# ['crazydev', 'erlang', 'funcprog', 'csharp', 'go', 'clojure', 'epam_systems', 'typescript', 'i_am_advertising', 'algorithms']
# Приветствую!
# Сегодня вечером пришло уведомление от Cloudmouse об удалении все виртуальных серверов.
# ['hosting']
# ['desktop_environment', 'i_am_advertising', 'history', 'google', 'twitter_api', 'helpdesk', 'epam_systems', 'nanosoft', 'tssolution', 'itsumma']
# Друзья, всем привет! Меня зовут Коля Архипов, я отвечаю за Research & Development в Delivery Club.
# Н
# ['vk', 'deliveryclub', 'ecommerce_development', 'research', 'ecommerce']
# ['study', 'vk', 'spbifmo', 'nanosoft', 'kelnik', 'sportmaster_lab', 'otus', 'sport_programming', 'skyeng', 'saas']
# Множится список продуктов и технологий, от которых компания Intel решила отказаться в этом году. Теп
# ['intel', 'arvr', 'video_tech', 'network_hardware']
# ['browsers', 'closet', 'firefox', 'desktops', 'droider', 'i_am_advertising', 'eset', 'hi', 'hardware', 'stc_spb']
# Привет! Меня зовут Ксюша, я старший продуктовый дизайнер в Ozon: проектирую разделы возвратов для ли
# ['ozontech', 'web_design', 'ui', 'productpm', 'design']
# ['google', 'i_am_advertising', 'desktop_environment', 'cloud_computing', 'closet', 'hi', 'kelnik', 'cad_cam', 'nanosoft', 'epam_systems']
# Современные браузеры не предоставляют возможность выбора - использовать WebRTC или не использовать.
# ['flashphoner', 'webdev', 'video', 'devops', 'video_conferencing']
# ['southbridge', 'virtualization', 's_admin', 'sys_admin', 'webdev', 'dataline', 'cloud_computing', 'server_side_optimization', 'san', 'desktop_environment']
# Анна Кикина первая из российских космонавтов полетит на Crew Dragon. Полет запланирован на 2022 год,
# ['space']
# ['artificial_intelligence', 'droider', 'crowdsourcing', 'cyberpunk', 'i_am_advertising', 'google', 'biotech', 'google_chrome', 'zadachki', 'nanosoft']
# Приветствую, username! Сегодня я расскажу тебе одну занимательную историю о нашем много ~~страдально
# ['galtsystems', 'sys_admin', 'it-infrastructure', 'server_side_optimization', 's_admin']
# ['i_am_advertising', 'io', 'venturecap', 'desktop_environment', 'service_desk', 'cloud_computing', 'startuprise', 'google', 'urban', 'office']
# Переход от JUnit4 к новой версии во многом изменил способ расширения функциональных возможностей тес
# ['otus', 'it_testing', 'java']
# ['java', 'net', 'scala', 'android_dev', 'vs', 'typescript', 'css', 'code_wtf', 'qt_software', 'google_chrome']
# Шведский стол в понимании любого оператора в мире, это не безлимитный интернет, а предложение в кото
# ['closet']
# ['DIY', 'i_am_advertising', 'cryptocurrency', 'google', 'contentmarketing', 'croc', 'erp', 'epam_systems', 'patents', 'office']
# В этом примере я покажу как создать «эффект аккордеона», который можно использовать как для меню, та
# ['closet']
# ['desktop_environment', 'webdev', 'google', 'i_am_advertising', 'epam_systems', 'paysto', 'uprock', 'crm', 'cloud_computing', 'hi']
# К каждого в жизни настает такой момент, когда что-то в быту безумно надоедает. Например, мне с супру
# ['dronk', 'gadgets', 'robot', 'lifehacks', 'futurenow']
# ['gtd', 'home_automation', 'health', 'transport', 'dronk', 'patents', 'DIY', 'croc', 'autogadgets', 'synesis']
# В этой статье, я хочу рассказать про свое решение проблемы с асинхронной функциональностью javascrip
# ['webdev', 'javascript', 'programming']
# ['crazydev', 'cpp', 'compilers', 'debug', 'i_am_advertising', 'csharp', 'google', 'nanosoft', 'localization', 'epam_systems']
# Когда начинается разговор об IAAS (упрощенно — виртуализации серверов), то сразу же звучат мантры "V
# ['virtualization']
# ['vuejs', 'shells', 'virtualization', 'sys_admin', 'typescript', 'desktop_environment', 'system_programming', 's_admin', 'sport_programming', 'webdev']
# Данный пост является логическим продолжением исследований, начатых в тыц и тыц.
# В первом посте я пис
# ['infosecurity']
# ['nanosoft', 'design', 'paysto', 'vector_graphics', 'net', 'php', 'facebook_api', 'mobile_dev', 'geo', 'DIY']
# Житель Флориды Кайл Хиппхен выиграл один из билетов на корабль SpaceX Dragon, которые разыгрывал IT-
# ['space', 'transport']
# ['i_am_advertising', 'google', 'wireless', 'desktop_environment', 'vk', 'history', 'itsumma', 'nanosoft', 'epam_systems', 'video']
# Есть небольшой закрытый сайт, на котором выкладывается музыка альбомами и пользователи сайта имеют в
# ['webdev']
# ['desktop_environment', 'webdev', 'angular', 'google', 'android_dev', 'nodejs', 'i_am_advertising', 'web_design', 'cloud_computing', 'epam_systems']
# Недавно viktorpanasiuk опубликовал задачу о конфетах, которая «зацепила» многих (в частности, koldyr
# ['nerepetitor', 'zadachki', 'maths']
# ['cryptocurrency', 'biotech', 'hosting', 'cloud_services', 'zadachki', 'sport_programming', 'stc_spb', 'algorithms', 'geo', 'business-laws']
# Radio Wave
# Этот сайт почти бесконечен, хотя его и сайтом-то назвать сложно, это что-то среднее между
# ['cyberpunk']
# ['i_am_advertising', 'desktop_environment', 'google', 'hi', 'timeweb', 'nanosoft', 'epam_systems', 'itsumma', 'crowdsourcing', 'history']
# Roadmap старта политик Google Play
# > Полный список изменений можно найти на support.google.com
# > Эта
# ['broadcast', 'android_dev', 'mobile_monetization', 'game_monetization', 'context']
# ['soft', 'scala', 'uipath', 'desktop_environment', 'nanosoft', 'google', 'i_am_advertising', 'hi', 'sberbank', 'video_conferencing']
# Разговоры о том, как важно составить профиль потенциального покупателя, и в соответствии с ним созда
# ['display_adv']
# ['closet', 'i_am_advertising', 'crowdsourcing', 'facebook_api', 'webdev', 'sport_programming', 'desktop_environment', 'hflabs', 'astronomy', 'browser_extensions']
# Учёные нашли свидетельства вращения крупнейших из известных нам структур – галактических нитей, прос
# ['astronomy']
# ['i_am_advertising', 'desktop_environment', 'service_desk', '3dtool', '3d-printers', 'google', 'it_testing', 'kelnik', 'timeweb', 'arvr']
# Браузер Brave уличили в том, что в отдельных случаях он подменяет URL в адресной строке, добавляя св
# ['itsumma', 'firefox', 'infosecurity', 'open_source', 'browsers']
# ['ui', 'paysto', 'web_design', 'usability', 'reactjs', 'webdev', 'vector_graphics', 'i_am_advertising', 'desktop_environment', 'javascript']
# Как уже многие знают, вышла русскоязычная версия Visual Studio 2010. В связи с этим, мы с компанией
# ['i_am_advertising']
# ['dell_technologies', 'fujitsu', 'cloud_mts', 'cloud_computing', 'usabilitylab', 'data_warehouse', 'epam_systems', 'i_am_advertising', 'closet', 'wp_dev']
# В 2018 году мы опубликовали обзор лучших инструментов аннотирования, которыми регулярно пользуемся.
# ['data_mining', 'image_processing', 'bigdata', 'machine_learning']
# ['i_am_advertising', 'desktop_environment', 'erp', 'google', 'epam_systems', 'cloud_computing', 'hi', 'crowdsourcing', 'nanosoft', 'localization']
# Не знаю, используют ли владельцы аккаунтов Gmail другие сервисы Google в той же мере, что и саму поч
# ['itcompanies']
# ['stc_spb', 'google', 'browsers', 'i_am_advertising', 'desktop_environment', 'zadachki', 'pt', 'facebook_api', 'ui', 'closet']
# Недавно компания «Ренессанс Страхование» опубликовала статью, в которой рассказала о программном про
# ['innoseti', 'p2p', 'itcompanies']
# ['browsers', 'i_am_advertising', 'crowdsourcing', 'zend_framework', 'paysto', 'google', 'croc', 'kelnik', 'epam_systems', 'usabilitylab']
# Wi-Fi Alliance и IEEE разрабатывают несколько стандартов — в том числе кандидата на звание Wi-Fi 7.
# ['vasexperts', 'itstandarts', 'wireless', 'netdev']
# ['nanosoft', 'i_am_advertising', 'desktop_environment', 'google', 'telebreeze', 'video_tech', 'thirdpin', 'wireless', 'epam_systems', 'crowdsourcing']
# Некоторое время назад озадачился поиском решения, которое позволило бы заменить стандартный «паджина
# ['yii']
# ['magento', 'php', 'doctrine', 'facebook_api', 'browsers', 'code_wtf', 'google_chrome', 'zadachki', 'scala', 'programming']
# Мы подвели итоги конкурса дизайна главной страницы Сбербанк Онлайн.
# ##### Дизайнеры
#    Всего было 33
# ['usabilitylab']
# ['dataline', 'cloud_computing', 'cloud_services', 'google', 'i_am_advertising', 'dcmiran', 'dell_technologies', 'office', 'hi', 'usabilitylab']
# Вчера создал для блога RSS-поток. Теперь, если выдержу писать постоянно, можно будет оперативно чита
# ['closet']
# ['desktop_environment', 'i_am_advertising', 'nanosoft', 'google', 'crowdsourcing', 'usabilitylab', 'epam_systems', 'kelnik', 'hosting', 'itsumma']
# (UPD: после шумихи эту проблему пофиксили, так что можете уже не проверять)
# Я давненько уже читаю Ха
# ['habr', 'browsers']
# ['usabilitylab', 'typography', 'i_am_advertising', 'angular', 'facebook_api', 'epam_systems', 'yii', 'paysto', 'javascript', 'html5']
# Современный Electron приложение состоит из трех модулей:
#    `main`;
#    `renderer`;
#    `preload`;
# Каж
# ['javascript']
# ['i_am_advertising', 'dcmiran', 'google', 'epam_systems', 'history', 'dell_technologies', 'cloud_services', 'billing', 'timeweb', 'nanosoft']
# Эта статья — взгляд на тестирование ММО с «другой стороны баррикад», с точки зрения геймера. Я хочу
# ['gamedev', 'game_testing']
# ['desktop_environment', 'i_am_advertising', 'google', 'hi', 'cad_cam', 'vk', 'nanosoft', 'crowdsourcing', 'epam_systems', 'itsumma']
# >
# [code]
# >     <hypnosis> 1. The human cell contains 75 MB of genetic information
# >     <hypnosis> 2
# ['closet']
# ['nodejs', 'typescript', 'php', 'meteorjs', 'vuejs', 'desktop_environment', 'uprock', 'webdev', 'browsers', 'google_chrome']
# Старт Falcon 9 с кораблем Crew Dragon. Источник фото: НАСА.
# 16 ноября в 03:27 по московскому времени
# ['space', 'futurenow']
# ['dcmiran', 'i_am_advertising', 'google', 'history', 'office', 'autogadgets', 'nanosoft', 'erp', 'vk', 'epam_systems']
# Одна из крупных проблем обучения с подкреплением - это неэффективность по данным. Да, мы можем обучи
# ['machine_learning', 'artificial_intelligence']
# ['sport_programming', 'sberbank', 'vk', 'sportmaster_lab', 'study', 'scrumtrek', 'weban', 'wunderfund', 'web_testing', 'skyeng']
# Меломаны всегда говорили, что у виниловых записей качество звука выше, по сравнению с компакт-дискам
# ['closet']
# ['browsers', 'usabilitylab', 'desktop_environment', 'eset', 'closet', 'opera', 'video', 'videocards', 'nanosoft', 'comerando']
# #### Счастливый случай или судьба
# Безусловно, WUD 2011 в Минске стал одним из самых интересных и зна
# ['ui']
# ['career', 'google', 'agile', 'desktop_environment', 'i_am_advertising', 'erp', 'crm', 'croc', 'vector_graphics', 'service_desk']
# При посещении веб-сайта браузер или другое клиентское приложение обычно посылает веб-серверу информа
# ['dcmiran', 'infosecurity', 'webdev', 'browsers', 'history']
# ['nanosoft', 'i_am_advertising', 'facebook_api', 'webdev', 'browsers', 'google_chrome', 'desktop_environment', 'php', 'docsvision', 'closet']
# Крупные корпорации США, оценив экономию средств от использования Linux для решения узких задач (хран
# ['linux']
# ['hosting', 'cryptocurrency', 'eset', 'open_source', 'desktop_environment', 'soft', 'data_warehouse', 'desktops', 'crowdsourcing', 'i_am_advertising']
# Заведя для себя «почту для домена» на Яндексе, я решил открыть свободную регистрацию посторонним юзе
# ['sys_admin']
# ['desktop_environment', 'i_am_advertising', 'google', 'crowdsourcing', 'service_desk', 'industrial_control_system', 'kelnik', 'nanosoft', 'hi', 'itsumma']
# Инструменты Business Intelligence (BI) за последние несколько лет проникли почти во все виды бизнеса
# ['playrix', 'analysis_design', 'it-infrastructure', 'soft']
# ['technical_writing', 'vk', 'study', 'programming', 'nanosoft', 'reactjs', 'typescript', 'scrumtrek', 'unidata', 'productivity_inside']
# Немного теории.
# Для начала разберемся с тем, что такое лошадиные силы и устроим небольшой экскурс в
# ['zadachki', 'maths', 'physics']
# ['closet', 'energy', 'google_chrome', 'gadgets', 'comptek', 'soft', 'usabilitylab', 'hosting', 'tablets', 'telebreeze']
# Вот и закончилась эта эпопея со звонками, экспертизами, судами, чтением законов, статей и нервотрепк
# ['business-laws']
# ['i_am_advertising', 'desktop_environment', 'fujitsu', 'google', 'nanosoft', 'epam_systems', 'history', 'itsumma', 'crowdsourcing', 'geo']
# Предыдущая часть
# После того, как вы создали эскизы страниц вашего приложения и определили пути навиг
# ['wp_dev']
# ['opera', 'yii', 'typography', 'ui', 'desktop_environment', 'usabilitylab', 'i_am_advertising', 'google', 'nanosoft', 'webdev']
# Часть 1. История систем автоматизации
# Часть 2. Немного про ПЛК
# Часть 3. Мифы on-line модификации при
# ['analysis_design', 'industrial_control_system', 'scada']
# ['hi', 'synesis', 'telebreeze', 'dell_technologies', 'nanosoft', 'itsumma', '1cloud', 'home_automation', 'wireless', 'timeweb']
# Продолжаем разбор лаб с VulnHub. На этот раз будем разбирать решение CTF с недавней конференции по и
# ['infosecurity', 'ctf']
# ['browsers', 'browser_extensions', 'desktop_environment', 'erp', 'web_testing', 'webdev', 'i_am_advertising', 'google', 'vuejs', 'crm']
# Вторая серия мульта от господина Куваева о службе техподдержки одной компании. Если кто не видел пер
# ['closet']
# ['wireless', 'selectel', 'telebreeze', 'timeweb', 'comptek', 'energy', 'transport', 'futurenow', 'urban', 'multicopters']
# Ранее мы рассмотрели способы расчёта нарастающего (накопительного) итога в SQL. Самый распространённ
# ['sql']
# ['erp', 'docsvision', 'doctrine', 'crm', 'analysis_design', 'deliveryclub', 'epam_systems', 'api', 'angular', 'billing']
# Подборка мероприятий на неделю
# Владимир Лисин в Bellclub
#    27 января (понедельник)
#    Новая площадь
# ['hackathons', 'tech_events']
# ['desktop_environment', 'i_am_advertising', 'cloud_computing', 'google', 'nanosoft', 'hi', 'epam_systems', 'hflabs', 'itsumma', 'kelnik']
# Почему голосование по принципу большинства не обеспечивает выявление реальных предпочтений общества?
# ['programming']
# ['pay_system', 'p2p', 'i_am_advertising', 'paysto', 'usabilitylab', 'patents', 'research', 'pt', 'closet', 'algorithms']
# Приветствую. Недавно я наткнулся на статью товарища Dywar «Интересные заметки по C# и CLR» и заинтер
# ['net', 'csharp']
# ['i_am_advertising', 'controllers', 'auriga', 'arduino', 'usabilitylab', 'dell_technologies', 'debug', 'google', 'nanosoft', 'kelnik']
# Я занимаюсь созданием анализатора PVS-Studio, выявляющего ошибки в исходном коде приложений на языке
# ['pvs-studio']
# ['i_am_advertising', 'google', 'desktop_environment', 'cad_cam', 'system_programming', 'crm', 'epam_systems', 'paysto', 'crowdsourcing', 'history']
# Golang United — комьюнити, основанное опытными разработчиками EPAM, объединив экспертизу участников
# ['epam_systems', 'programming', 'go', 'career', 'devops']
# ['i_am_advertising', 'wp_dev', 'google', 'soft', 'open_source', 'nanosoft', 'video_conferencing', 'kelnik', 'data_mining', 'mobile_dev']
# Во время чтения «Происхождения видов путем естественного отбора» Чарльза Дарвина, меня не покидало с
# ['programming', 'analysis_design', 'dev_management']
# ['i_am_advertising', 'dcmiran', 'erp', 'croc', 'google', 'hi', 'nanosoft', 'vector_graphics', 'kelnik', 'video']
# Для пользователей Opera и любителей визуальных закладок у нас есть хорошая новость. Теперь при добав
# ['yandex']
# ['yandex', 'i_am_advertising', 'video_conferencing', 'google', 'desktop_environment', 'hi', 'epam_systems', 'nanosoft', 'erp', 'saas']
# Эта статья могла бы получить название "Как PVS-Studio защищает от поспешных правок кода, пример N7".
# ['pvs-studio', 'programming']
# ['win_dev', 'csharp', 'i_am_advertising', 'qt_software', 'desktop_environment', 'net', 'design', 'cad_cam', 'kelnik', 'nanosoft']
# Иудейский интернет-журнал Tabletmag планирует бороться с интернет-троллями очень оригинальным методо
# ['social_networks']
# ['contentmarketing', 'data_mining', 'biotech', 'artificial_intelligence', 'i_am_advertising', 'display_adv', 'context', 'google', 'cyberpunk', 'bigdata']
# За два с небольшим месяца существования сайта Barbiegirls.com (он стартовал практически одновременно
# ['closet']
# ['zadachki', 'i_am_advertising', 'desktop_environment', 'epam_systems', 'usabilitylab', 'google', 'hi', 'hosting', 'vector_graphics', 'closet']
# 1 декабря 2022 года в «Яндекс Станциях» появился режим радионяни. С помощью умных колонок «Яндекса»
# ['cloud_services', 'gadgets', 'social_networks', 'home_automation', 'itcompanies']
# ['cloud_services', 'geo', 'video_conferencing', 'google', 'wearable_electronics', 'soft', 'nanosoft', 'android_dev', 'video', 'design']
# У jQuery есть встроенная фича — если сервер ответит с content-type=text/javascript библиотека выполн
# ['infosecurity', 'webdev', 'ror']
# ['google', 'i_am_advertising', 'nanosoft', 'angular', 'desktop_environment', 'epam_systems', 'crazydev', 'ui', 'itsumma', 'kelnik']
# Свой первый квадрокоптер я купил более двух лет назад и купил я его, чтобы открыть новые ракурсы для
# ['dronk', 'gadgets', 'robot', 'video_tech', 'multicopters']
# ['tuturu', 'unidata', 'sberbank', 'synesis', 'spbifmo', 'nanosoft', 'telebreeze', 'vk', 'DIY', 'thirdpin']
# ## Задача
# Некоторая контора задалась идеей измерить эффективность системы энергосбережения Ubuntu. П
# ['linux']
# ['win_dev', 'qt_software', 'angular', 'google_chrome', 'csharp', 'drupal', 'i_am_advertising', 'vuejs', 'desktop_environment', 'net']
# Илон Маск поделился в Twitter подробностями проекта нейроинтерфейса Neuralink.Он рассказал, что уста
# ['popular_science', 'biotech', 'brain', 'health', 'futurenow']
# ['i_am_advertising', 'nanosoft', 'artificial_intelligence', 'desktop_environment', 'google', 'vector_graphics', 'timeweb', 'crowdsourcing', 'hi', 'biotech']
# Одно из главных достоинств и вместе с тем самый спорный момент Web 2.0 — привлечение посетителей сай
# ['media_management']
# ['urban', 'i_am_advertising', 'research', 'facebook_api', 'synesis', 'video', 'google', 'transport', 'desktop_environment', 'crowdsourcing']
# Это не очередная статья про Dagger и его возможности. Не будет ни слова про другие DI фреймворки.
# Це
# ['android_dev']
# ['csharp', 'api', 'facebook_api', 'angular', 'desktop_environment', 'auriga', 'debug', 'cpp', 'controllers', 'hi']
# Уже довольно давно мы представили Вам оборудование Siklu — доступные производительные решения диапаз
# ['comptek']
# ['i_am_advertising', 'google', 'desktop_environment', 'epam_systems', 'hi', 'crowdsourcing', 'erp', 'research', 'infographics', 'timeweb']
# В статье приведу результат решения задачи по организации маршрутизации между виртуальными машинами н
# ['it-infrastructure', 'virtualization', 'network_technologies']
# ['virtualization', 'server_side_optimization', 'google', 'typescript', 'southbridge', 'selectel', 'desktop_environment', 'tssolution', 'sys_admin', 'localization']
# #### Почему Опера так популярна в России и Украине?
# По данным статистики (Bigmir, LiveInternet, ссыл
# ['opera']
# ['crowdsourcing', 'contentmarketing', 'usabilitylab', 'i_am_advertising', 'google', 'closet', 'design', 'biotech', 'audiomania', 'infographics']
# > В преддверии старта базового курса по Machine Learning, подготовили для вас интересный перевод, а
# ['otus', 'programming', 'bigdata', 'machine_learning']
# ['i_am_advertising', 'desktop_environment', 'nanosoft', 'google', 'crowdsourcing', 'research', 'itsumma', 'hi', 'office', 'epam_systems']
# Сергей Бабенко, центр инженерных разработок Москва
# Жизнь, как известно, не стоит на месте, новые дом
# ['google']
# ['network_hardware', 'server_side_optimization', 'office', 'southbridge', 'i_am_advertising', 's_admin', 'comptek', 'google', 'crowdsourcing', 'network_technologies']
# Всего четыре года назад у Xiaomi не было ни одного телефона. Сегодня этот стартап оценивается в 45 м
# ['pm', 'gtd', 'venturecap', 'productpm']
# ['google', 'cad_cam', 'ui', 'video', 'paysto', 'soft', 'video_conferencing', 'stc_spb', 'nanosoft', 'i_am_advertising']
# Вы все еще не знаете, как лучше организовать передачу файлов по сети на компьютеры под управлением W
# ['win_dev']
# ['i_am_advertising', 'desktop_environment', 'nanosoft', 'google', 'office', 'crowdsourcing', 'geo', 'industrial_control_system', 'epam_systems', 'crm']
# Дизайнер Shay Shafranek так заколебался, разрабатывая электронную линейку, что совершенно не находил
# ['gadgets']
# ['usabilitylab', 'multicopters', 'i_am_advertising', 'erp', 'transport', 'telebreeze', 'cryptocurrency', 'rozetked', 'closet', 'space']
# #### Содержание:
#    Что такое JWT?
#      Заголовок
#      Полезная нагрузка
#      Подпись
#      Что такое
# ['alexhost', 'infosecurity', 'web_testing']
# ['ctf', 'alexhost', 'eset', 'i_am_advertising', 'facebook_api', 'cloud_computing', 'auriga', 'google', 'desktop_environment', 'api']
# ### Вступление
# ...
# Волею судьбы мне периодически приходится просматривать Хабрахабр с отключенными картинками и это не
# ['habr']
# ['i_am_advertising', 'google', 'facebook_api', 'erp', 'nanosoft', 'timeweb', 'vk', 'usabilitylab', 'ui', 'stc_spb']
# Десять лет назад корпорация Google с помпой объявила о старте конкурса, который получил название Goo
# ['space']
# ['desktop_environment', 'i_am_advertising', 'history', 'google', 'scrumtrek', 'hi', 'nanosoft', 'epam_systems', 'erp', 'office']
# Когда я учился программировать, меня всегда раздражало решать на практиках неинтересные задачи. Тепе
# ['closet']
# ['opera', 'zadachki', 'unity', 'desktop_environment', 'eset', 'csharp', 'linux', 'alexhost', 'acelab', 'facebook_api']
# Все началось с того, что министерство торговли США включило Huawei в список компаний, с которыми зап
# ['inDrive', 'mobile_dev', 'android_dev']
# ['i_am_advertising', 'billing', 'google', 'croc', 'usabilitylab', 'dataline', 'epam_systems', 'hi', 'cloud_mts', 'deliveryclub']
# Мы продолжаем рассказывать об особенностях инклюзивного образования в МГТУ им. Баумана. В прошлой ст
# ['bmstu', 'programming', 'study', 'gadgets', 'engineering_systems']
# ['study', 'sport_programming', 'zadachki', 'nanosoft', 'desktop_environment', 'i_am_advertising', 'vk', 'scrumtrek', 'kelnik', 'weban']
# Добрый день, хабравчане. Еще один гаджет побыл у меня в руках целую неделю. Это BlackBerry Z10 – нов
# ['rozetked']
# ['nanosoft', 'desktop_environment', 'comptek', 'desktops', 'video_conferencing', 'hardware', 'cloud_computing', 'prolan', 'lanit', 'itsumma']
# Минэкономразвития включило в проект основных направлений деятельности правительства России на период
# ['p2p']
# ['closet', 'desktop_environment', 'code_wtf', 'crowdsourcing', 'google', 'erp', 'i_am_advertising', 'copyright', 'epam_systems', 'vector_graphics']
# В блоге madrobots мы часто касаемся темы Кикстартера и его влияния на развитие технологий. Много все
# ['madrobots']
# ['wirenboard', 'nanosoft', 'desktop_environment', 'thirdpin', 'hi', 'wearable_electronics', 'crm', 'i_am_advertising', 'video_tech', 'epam_systems']
# Прим. перев.: для понимания данной статьи необходимо обладать начальными знаниями Angular: что такое
# ['webdev', 'javascript', 'angular', 'typescript']
# ['django', 'code_wtf', 'erlang', 'html5', 'drupal', 'doctrine', 'mipt', 'javascript', 'api', 'google_chrome']
# Memory has been studied for dozens of years, yet common myths surrounding it are refusing to die out
# ['spbifmo', 'gtd', 'study', 'brain', 'health']
# ['i_am_advertising', 'desktop_environment', 'google', 'nanosoft', 'itsumma', 'hi', 'epam_systems', 'kelnik', 'timeweb', 'crowdsourcing']
# «Правильные люди на правильных местах важнее, чем правильная стратегия», – сказал Джек Уэлч, экс-ген
# ['hr_management']
# ['study', 'regionsoft', 'technical_writing', 'read', 'pm', 'tuturu', 'usability', 'scrumtrek', 'i_am_advertising', 'ui']
# Компания Apple разрабатывает сразу несколько новых процессоров для своих устройств Mac. В линейке чи
# ['cpu']
# ['desktops', 'desktop_environment', 'dcmiran', 'cpu', 'fujitsu', 'soft', 'hardware', 'dell_technologies', 'cloud_services', 'notebooks']
# В сентябре этого года должна была выйти мобильная игра Titan World от Unstoppable – минского офиса G
# ['hi', 'ios_dev', '3d_graphics', 'gamedev', 'algorithms']
# ['nanosoft', 'i_am_advertising', 'desktop_environment', 'google', 'history', 'infographics', 'agile', 'timeweb', 'hi', 'apps_design']
# Группа строений кампуса Microsoft от No16 до No18 многие годы служила домом для команды разработчико
# ['debug', 'pm']
# ['win_dev', 'soft', 'video_conferencing', 'desktop_environment', 'cloud_services', 'typescript', 'tech_events', 'system_programming', 'browsers', 'programming']
# В концепте телефона Edge, придуманного дизайнером Крисом Оуэнсом, не уделено никакого внимания начин
# ['design']
# ['design', 'php', 'closet', 'yii', 'html5', 'DIY', 'i_am_advertising', 'webdev', 'usabilitylab', 'ecommerce_development']
# Мы привыкли жить в условиях постоянно изменяющегося облика городов. Старые здания исчезают — появляю
# ['vk', 'popular_science', 'urban']
# ['desktop_environment', 'nanosoft', 'i_am_advertising', 'erp', 'google', 'sport_programming', 'epam_systems', 'croc', 'cloud_computing', 'stc_spb']
# Яндекс представил новую версию результатов в «поиске по блогам».
# Со слов Антона Волнухина, они учли
# ['itcompanies']
# ['facebook_api', 'python', 'twitter_api', 'css', 'sport_programming', 'opera', 'drupal', 'zadachki', 'django', 'google']
# Южнокорейская компания Samsung пока не приняла окончательное решение возобновить деятельность в Росс
# ['ecommerce', 'sales', 'gadgets', 'smartphones', 'itcompanies']
# ['fujitsu', 'dell_technologies', 'cloud_mts', 'comptek', 'i_am_advertising', 'hi', 'DIY', 'office', 'ecommerce_development', 'croc']
# Приветствую всех!
# Держу сайты на двух разных виртуальных хостингах (не VPS, а shared hosting). Сайты
# ['php']
# ['i_am_advertising', 'desktop_environment', 'google', 'zend_framework', 'sys_admin', 'nanosoft', 'epam_systems', 'hi', 'itsumma', 'cad_cam']
# Большинство фаундеров стартуют на собственные деньги, и первый год жизни их проекты испытывают сильн
# ['puzzleenglish', 'startuprise']
# ['startuprise', 'office', 'research', 'urban', 'tuturu', 'vc', 'business_models', 'productpm', 'payonline', 'saas']
# Мне кажется, бунт роботов не близок. Я начал писать статью про то, что наша команда приступила к ада
# ['pvs-studio', 'c', 'robo_dev', 'controllers']
# ['doctrine', 'browsers', 'alexhost', 'eset', 'firefox', 'google', 'i_am_advertising', 'facebook_api', 'browser_extensions', 'nanosoft']
# Сегодня для активации кода на AdWords пошел создавать очередной почтовый ящик.
# После заполнения всех
# ['closet']
# ['i_am_advertising', 'nanosoft', 'desktop_environment', 'google', 'soft', 'epam_systems', 'video_conferencing', 'crowdsourcing', 'web_monetization', 'wp_dev']
# Недавно на хабре появилась неплохая статья про вычисление N-ного числа фибоначи за O(log N) арифмети
# ['algorithms', 'compilers']
# ['zadachki', 'stc_spb', 'sport_programming', 'algorithms', 'python', 'nerepetitor', 'open_source', 'io', 'typography', 'vk']
# Итак, у нас 1000 окопов в ряд (не по кругу). В одном из них (не видно в каком) сидит солдат по имени
# ['zadachki']
# ['cloud_services', 'closet', 'business_models', 'business-laws', 'cryptocurrency', 'crowdsourcing', 'erp', 'ui', 'conpay', 'i_am_advertising']
# Продолжаем, самое легкое позади! А теперь к самому сложному и интересному. Если лень читать, то ниже
# ['programming', 'antikvariat', 'DIY', 'games']
# ['i_am_advertising', 'desktop_environment', 'nanosoft', 'google', 'cloud_computing', 'hi', 'epam_systems', 'zend_framework', 'crowdsourcing', 'kelnik']
# Во всем мире нестабильность, террористы взрываются и лопаются, погода преподносит неприятные сюрприз
# ['media_management']
# ['office', 'paysto', 'history', 'gtd', 'sport_programming', 'kelnik', 'zadachki', 'erp', 'i_am_advertising', 'crm']
# Думаю уже все МНОГО ЧИТАЛИ про вчерашнюю презентацию Apple.
# ~~Весь интрнет~~ Хабр переполнен размышл
# ['closet']
# ['i_am_advertising', 'google', 'nanosoft', 'erp', 'epam_systems', 'cloud_services', 'arduino', 'timeweb', 'dcmiran', 'vk']
# После перехода к Steam Direct предстоит ответить на множество вопросов, поэтому среди потребителей и
# ['gamedev']
# ['desktop_environment', 'i_am_advertising', 'google', 'sport_programming', 'usabilitylab', 'hi', 'wunderfund', 'crowdsourcing', 'crm', 'epam_systems']
# Технические онлайн-сессии Dell Technologies продолжаются. В прошлый раз мы получили много регистраци
# ['dell_technologies', 's_admin', 'dwh', 'desktops', 'kubernetes']
# ['dataline', 'nanosoft', 'google', 'open_source', 'cloud_computing', 'virtualization', 'erp', 'desktop_environment', 'it-infrastructure', 'dell_technologies']
# В среду Facebook представила новый сервис «questions and answers». С помощью, которого пользователи
# ['closet']
# ['crowdsourcing', 'usability', 'google', 'desktop_environment', 'erp', 'i_am_advertising', 'timeweb', 'epam_systems', 'vector_graphics', 'closet']
# Компания Sony обновила и без того неслабые спецификации своего недешевого UMPC VAIO UX, первая модиф
# ['gadgets']
# ['system_programming', 'server_side_optimization', 'desktop_environment', 'i_am_advertising', 'vk', 'google', 'soft', 'erp', 'timeweb', 'hi']
# Стоит ли публиковать на Хабре обзор девайса, не имеющего, если судить поверхностно, никакого отношен
# ['DIY']
# ['patents', 'image_processing', 'nanosoft', 'i_am_advertising', 'multicopters', 'crowdsourcing', 'infographics', 'usabilitylab', 'cryptocurrency', 'transport']
# # Введение
# Сегодня мы будем рассматривать такой достаточно известный музыкальный сервис, как Yandex.
# ['python', 'api']
# ['cloud_computing', 'billing', 'i_am_advertising', 'desktop_environment', 'google', 'usabilitylab', 'cisconetworks', 'hi', 'api', 'epam_systems']
# Друзья, мы определили новую дату проведения митапа Data People by GlowByte и приглашаем присоединить
# ['glowbyte', 'bigdata', 'tech_events']
# ['desktop_environment', 'nanosoft', 'i_am_advertising', 'closet', 'typography', 'io', 'algorithms', 'google', 'hi', 'geo']
# Правильно функционирующая ИТ-инфраструктура — основа для успешного бизнеса. Важную роль в этом играе
# ['dell_technologies']
# ['cloud_services', 'cloud_computing', 'google', 'server_side_optimization', 'hosting', 'angular', 'i_am_advertising', 'virtualization', 'erp', 'hflabs']
# Конечно же, новости этой недели связаны по большей части с Apple. Компания презентовала два новых iP
# ['ios_dev', 'mobile_dev', 'android_dev']
# ['i_am_advertising', 'erp', 'desktop_environment', 'nanosoft', 'google', 'timeweb', 'hi', 'itsumma', 'crowdsourcing', 'epam_systems']
# Собственно читаю сейчас довольно известную статью Рея Курцвейля «Слияние человека с машиной» и думаю
# ['cyberpunk']
# ['study', 'spbifmo', 'i_am_advertising', 'read', 'puzzleenglish', 'closet', 'parallels', 'sberbank', 'nanosoft', 'synesis']
# Описание и схема построения в вики.
# ['closet']
# ['google_chrome', 'desktop_environment', 'browsers', 'google', 'android_dev', 'code_wtf', 'i_am_advertising', 'cloud_services', 'usabilitylab', 'droider']
# Генерировать код на .Net можно несколькими способами:
#    Reflection Emit. Доступен с версии .Net 1.0
# ['net']
# ['i_am_advertising', 'desktop_environment', 'google', 'closet', 'paysto', 'crowdsourcing', 'epam_systems', 'itsumma', 'timeweb', 'cloud_computing']
# Один из эскизов главного здания Национального космического центра
# Уже в этом году начнётся строитель
# ['office', 'space']
# ['office', 'pt', 'patents', 'transport', 'service_desk', 'video_conferencing', 'dataline', 'energy', 'crm', 'space']
# Судя по появившимся в сети изображениям, Sony завершила разработку двух новых моделей электронных чи
# ['hardware']
# ['desktop_environment', 'i_am_advertising', 'crazydev', 'django', 'erlang', 'design', 'usabilitylab', 'vector_graphics', 'debug', 'cms']
# Спойлер: атомарный дизайн
# Это работа является логическим продолжением моего первого подробного текст
# ['web_design', 'crazydev', 'css', 'javascript', 'ui']
# ['i_am_advertising', 'desktop_environment', 'nanosoft', 'google', 'epam_systems', 'timeweb', 'cloud_computing', 'kelnik', 'vk', 'crowdsourcing']
# Здравствуйте, уважаемые участники Habrahabr.
# При том, что Хабр — портал, ориентированный на программ
# ['DIY']
# ['scada', 'nanosoft', 'desktop_environment', 'prolan', 'synesis', 'thirdpin', 'i_am_advertising', 'telebreeze', 'system_programming', 'ruvds']
# В рамках рекламной компании нашего проекта webonmap.ru, мы закупили корпоративный пакет на habr.ru в
# ['webonmap']
# ['cloud_services', 'closet', 'crowdsourcing', 'cloud_computing', 'i_am_advertising', 'copyright', 'paysto', 'epam_systems', 'google', 'helpdesk']
# Первую часть статьи вы можете найти по этой ссылке.
# Идея разностной машины посетила Чарльза Бэббиджа
# ['maths']
# ['desktop_environment', 'ua-hosting', 'i_am_advertising', 'spbifmo', 'google', 'crowdsourcing', 'nanosoft', 'erp', 'vk', 'epam_systems']
# В навигации по блогам, текстам, прямому эфиру встречаются ссылки «Назад» и «Вперед». При этом «Назад
# ['habr']
# ['ui', 'cloud_services', 'i_am_advertising', 'stc_spb', 'typography', 'r', 'vk_api', 'matlab', 'nerepetitor', 'google']
# 20 декабря российский суд оштрафовал на 30 тыс. рублей бывшего сотрудника ГИБДД за майнинг на работе
# ['business-laws', 'hardware', 'cryptocurrency', 'itcompanies']
# ['croc', 'ecm', 'career', 'agile', 'billing', '1cloud', 'dev_management', 'nanosoft', 'crm', 'business_models']
# Думаю многие видели или слышали об OpenStreetMap — неплохом источнике карт, которые рисуют сами поль
# ['openstreetmap']
# ['i_am_advertising', 'desktop_environment', 'statistics', 'google', 'hi', 'kelnik', 'nanosoft', 'epam_systems', 'itsumma', 'infographics']
# На самом деле девушки не так уж и мало играют в видеоигры. Попробую опровергнуть некоторые высказыва
# ['gamedev']
# ['typography', 'zadachki', 'vector_graphics', 'i_am_advertising', 'desktop_environment', 'google', 'DIY', 'unity', 'usabilitylab', 'io']
# Охотникам за киберугрозами удалось заглянуть на «кухню» группировки хакеров индийского происхождения
# ['ruvds', 'infosecurity']
# ['croc', 'i_am_advertising', 'nanosoft', 'billing', 'google', 'cloud_mts', 'dell_technologies', 'dataline', 'kelnik', 'data_warehouse']
# Участники одного из форумов утверждают, что им удалось полностью разблокировать iPhone для использов
# ['closet']
# ['rozetked', 'usabilitylab', 'i_am_advertising', 'google', 'desktop_environment', 'tablets', 'soft', 'epam_systems', 'hi', 'nanosoft']
# Снова привет, на связи Алексей Приставко, и это вторая часть моего рассказа об объектном S3 хранилищ
# ['dataline', 'it-infrastructure', 'dwh', 'data_warehouse', 'cloud_services']
# ['s_admin', 'southbridge', 'hi', 'open_source', 'i_am_advertising', 'bigdata', 'analysis_design', 'server_side_optimization', 'billing', 'cloud_computing']
# Кросс-пост с моего технического блога
# Такой вот заумный вопрос я прочитал в заголовке статьи Communi
# ['closet']
# ['desktop_environment', 'google', 'i_am_advertising', 'nanosoft', 'epam_systems', 'hi', 'usabilitylab', 'business_models', 'video', 'closet']
# Новая версия официального клиента для популярнейшей Peer 2 Peer сети BitTorrent. Шестая версия — это
# ['closet']
# ['win_dev', 'soft', 'desktop_environment', 'google', 'i_am_advertising', 'vk', 'sport_programming', 'usabilitylab', 'dcmiran', 'unity']
# Глава аналитического отдела Twitter — Кевин Вейл, несколько дней назад опубликовал интересные цифры
# ['social_networks']
# ['i_am_advertising', 'twitter_api', 'gtd', 'health', 'tssolution', 'server_side_optimization', 'crm', 'net', 'biotech', 'design']
# Генеральный директор по исследованиям и разработкам корпорации Intel — Камиль Исаев, именно ему стои
# ['intel']
# ['desktop_environment', 'i_am_advertising', 'google', 'erp', 'helpdesk', 'hi', 'epam_systems', 'timeweb', 'nanosoft', 'agile']
# ### Как узнали возраст Вселенной?
# В 1929 году американский астроном Эдвин Хаббл обнаружил, что галак
# ['r', 'popular_science', 'astronomy']
# ['webdev', 'yii', 'desktop_environment', 'facebook_api', 'django', 'meteorjs', 'typography', 'zadachki', 'browsers', 'code_wtf']
# Управление по санитарному надзору за качеством продуктов питания и медикаментов США (FDA) выдало раз
# ['health']
# ['google', 'i_am_advertising', 'nanosoft', 'closet', 'stc_spb', 'hi', 'bigdata', 'cryptocurrency', 'cad_cam', 'hflabs']
# Джейсон Коул, аспирант имперского колледжа Лондона предложил рассчитывать идеальное место для Wi-Fi
# ['smartphones', 'network_hardware', 'physics']
# ['i_am_advertising', 'google', 'desktop_environment', 'erp', 'hi', 'nanosoft', 'open_source', 'web_monetization', 'usabilitylab', 'weban']
# Благодаря инициативе группы пользователей из Ирана, на Codeforces в субботу, 30-го июля в 10:00 по М
# ['sport_programming']
# ['desktop_environment', 'programming', 'i_am_advertising', 'python', 'refactoring', 'crm', 'sport_programming', 'sportmaster_lab', 'google', 'webdev']
# Компания Defense Distributed занимается разработкой и распространением чертежей деталей огнестрельно
# ['open_source']
# ['i_am_advertising', 'cloud_services', 'crowdsourcing', 'cloud_computing', '3d_graphics', 'design', 'sport_programming', 'games', 'dell_technologies', 'kelnik']

# %% [markdown]
# Doesn't look that great.

# %%
metrics = RankingMetrics(test_target, predicts)

# %%
print(f"Average dcg of model on test dataset: {np.mean(metrics.dcg()).item():.4f}")
print(f"Average ndcg of model on test dataset: {np.mean(metrics.ndcg()).item():.4f}")
# Out:
# Average dcg of model on test dataset: 0.1053
# Average ndcg of model on test dataset: 0.0686

# %% [markdown]
# Нам явно есть куда расти! (у ndcg максимум = 1)

# %%
best_5 = np.argsort(metrics.ndcg())[-5:]
worst_5 = np.argsort(metrics.ndcg())[:5]
print(best_5, worst_5)
# Out:
# [ 67 161 310 453 436] [384 149 494 232 158]

# %%
def print_sample(
    id: int,
    target: Target,
    metric: RankingMetrics,
    df: pd.DataFrame,
    predicts: np.ndarray,
):
    sample_dcg = metric.dcg()[id]
    sample_ndcg = metric.ndcg()[id]
    text = df.iloc[id]["text_markdown"]
    targets = df.iloc[id]["hubs"]
    predicted_ranking = [target.labels[i] for i in predicts[id].argsort()[::-1]]

    target_predicts = [
        predicts[id][target.label_to_id(t_item)].item() for t_item in targets
    ]
    top_predicts = [
        predicts[id][target.label_to_id(item)].item() for item in predicted_ranking
    ]

    print(f"id: {id}")
    print(f"dcg: {sample_dcg}")
    print(f"ndcg: {sample_ndcg}")
    print(f"text:\n {text[:100]}")
    print(f"...")
    print(f"{text[-100:]}")
    print(f"targets: {list(zip(targets, target_predicts))}")
    print(f"predict: {list(zip(predicted_ranking[:20], top_predicts[:20]))}")

# %%
for id in worst_5:
    print_sample(id, test_target, metrics, test_df, predicts)
# Out:
# id: 384
# dcg: 0.0029940119760479044
# ndcg: 0.0029940119760479044
# text:
#  Привет Хабр! А вот и снова мы! На перекор множествам скептиков, которые нередко встречались на нашем
# ...
# Следующим шагом будет объединение задач распознавания и управления манипулятором на реальном роботе.
# targets: [('tod', 0.0004877964674960822)]
# predict: [('nanosoft', 0.9293713569641113), ('cad_cam', 0.9181030988693237), ('dcmiran', 0.9159507751464844), ('comptek', 0.9130692481994629), ('fujitsu', 0.8883840441703796), ('dell_technologies', 0.8808190822601318), ('vector_graphics', 0.8611271977424622), ('dwh', 0.8495913147926331), ('galtsystems', 0.8257451057434082), ('stc_spb', 0.798514723777771), ('croc', 0.7880276441574097), ('geo', 0.771212637424469), ('engineering_systems', 0.7657341361045837), ('machine_learning', 0.7610746622085571), ('first', 0.7586255073547363), ('i_am_advertising', 0.7534132599830627), ('industrial_control_system', 0.7369108200073242), ('dataline', 0.7349568605422974), ('1cloud', 0.727464497089386), ('cloud_mts', 0.7264947295188904)]
# id: 149
# dcg: 0.0030211480362537764
# ndcg: 0.0030211480362537764
# text:
#  Вот и закончилась эта эпопея со звонками, экспертизами, судами, чтением законов, статей и нервотрепк
# ...
# ие
# ~~Остальные если и есть, то только в виде бумажек. Посмотрю дома.~~ Остальных нет. Всё в мусорке.
# targets: [('business-laws', 0.00012415205128490925)]
# predict: [('i_am_advertising', 0.9446808099746704), ('desktop_environment', 0.9031204581260681), ('fujitsu', 0.8561293482780457), ('google', 0.8496883511543274), ('nanosoft', 0.7926546335220337), ('epam_systems', 0.7852526307106018), ('history', 0.7431527972221375), ('itsumma', 0.7103332281112671), ('crowdsourcing', 0.7091330885887146), ('geo', 0.6814948916435242), ('erp', 0.6806174516677856), ('clojure', 0.6461626887321472), ('paysto', 0.6458274126052856), ('timeweb', 0.6307185292243958), ('hi', 0.6194334626197815), ('prolan', 0.6148014664649963), ('hflabs', 0.5989100337028503), ('telebreeze', 0.5882131457328796), ('jetinfosystems', 0.5868146419525146), ('otus', 0.5843329429626465)]
# id: 494
# dcg: 0.0030303030303030303
# ndcg: 0.0030303030303030303
# text:
#  Генеральный директор по исследованиям и разработкам корпорации Intel — Камиль Исаев, именно ему стои
# ...
# м успеха всем участникам и организаторам конкурса и будем надеяться на отличные результаты. Спасибо.
# targets: [('intel', 0.00014839648792985827)]
# predict: [('desktop_environment', 0.9154061675071716), ('i_am_advertising', 0.9109147191047668), ('google', 0.8740085959434509), ('erp', 0.8695467710494995), ('helpdesk', 0.846015989780426), ('hi', 0.7901756763458252), ('epam_systems', 0.7777725458145142), ('timeweb', 0.7755146026611328), ('nanosoft', 0.7670361399650574), ('agile', 0.7641091346740723), ('lifehacks', 0.7583567500114441), ('career', 0.735649585723877), ('itsumma', 0.7011348605155945), ('cpu', 0.6990395188331604), ('usabilitylab', 0.6859660744667053), ('infographics', 0.6779270172119141), ('video', 0.6750077605247498), ('design', 0.6704296469688416), ('vector_graphics', 0.6603315472602844), ('cad_cam', 0.6528275609016418)]
# id: 232
# dcg: 0.0031545741324921135
# ndcg: 0.0031545741324921135
# text:
#  Уже больше года у меня лежит корпус от сгоревшего Xbox 360. Сначала, я думал его пристрою под что то
# ...
#  в PC.
# PS: Я понимаю что можно использовать ДаруДар, но тут я думаю найдется больше желающих.
# Москва
# targets: [('DIY', 0.0008147400221787393)]
# predict: [('closet', 0.9798832535743713), ('google', 0.9057426452636719), ('comerando', 0.8999240398406982), ('css', 0.863859236240387), ('nanosoft', 0.8473610281944275), ('i_am_advertising', 0.8273303508758545), ('timeweb', 0.807667076587677), ('epam_systems', 0.8056589365005493), ('doctrine', 0.7664756178855896), ('vector_graphics', 0.7571507692337036), ('browsers', 0.7490665912628174), ('webdev', 0.7480533123016357), ('paysto', 0.743512749671936), ('hi', 0.7308365702629089), ('history', 0.7247989177703857), ('patents', 0.7202023863792419), ('video', 0.7182498574256897), ('usabilitylab', 0.7141227126121521), ('itsumma', 0.6774070262908936), ('geo', 0.6726444959640503)]
# id: 158
# dcg: 0.0031847133757961785
# ndcg: 0.0031847133757961785
# text:
#  Я занимаюсь созданием анализатора PVS-Studio, выявляющего ошибки в исходном коде приложений на языке
# ...
# я разработки современных ресурсоемких приложений». http://www.viva64.com/ru/pvs-studio-presentation/
# targets: [('pvs-studio', 0.00076500722207129)]
# predict: [('i_am_advertising', 0.9079460501670837), ('google', 0.8639705777168274), ('desktop_environment', 0.8495280742645264), ('cad_cam', 0.8444616794586182), ('system_programming', 0.7707537412643433), ('crm', 0.7663339376449585), ('epam_systems', 0.7642631530761719), ('paysto', 0.7529774308204651), ('crowdsourcing', 0.7523532509803772), ('history', 0.7520502805709839), ('itsumma', 0.7377135157585144), ('hi', 0.7348458170890808), ('nanosoft', 0.7211329936981201), ('erp', 0.6925355792045593), ('geo', 0.6866220831871033), ('infographics', 0.6771556735038757), ('office', 0.6350242495536804), ('first', 0.6246749758720398), ('dataline', 0.6218581795692444), ('kelnik', 0.6094602346420288)]

# %% [markdown]
# You can see that some rare hubs are most problematic.

# %%
for id in best_5:
    print_sample(id, test_target, metrics, test_df, predicts)
# Out:
# id: 67
# dcg: 1.75
# ndcg: 0.9545454545454546
# text:
#  Перевод статьи «Building robust web apps with React: Part 1, in-browser prototypes», Matt Hinchliffe
# ...
# тимизации кода для браузера. Пожалуйста, комментируйте или твитните мне, я буду рад получить отзывы.
# targets: [('webdev', 0.9758679866790771), ('javascript', 0.9567009210586548), ('reactjs', 0.9893564581871033)]
# predict: [('reactjs', 0.9893564581871033), ('webdev', 0.9758679866790771), ('ui', 0.9587210416793823), ('javascript', 0.9567009210586548), ('nanosoft', 0.9445443749427795), ('usability', 0.9340246319770813), ('crazydev', 0.9211539030075073), ('localization', 0.9194872379302979), ('controllers', 0.9164429903030396), ('go', 0.910089910030365), ('technical_writing', 0.9059873819351196), ('vuejs', 0.8980258703231812), ('debug', 0.8955955505371094), ('erlang', 0.8737245202064514), ('programming', 0.8720690011978149), ('history', 0.8511224389076233), ('angular', 0.8485491275787354), ('paysto', 0.8331936001777649), ('otus', 0.8306916356086731), ('php', 0.8198253512382507)]
# id: 161
# dcg: 1.0
# ndcg: 1.0
# text:
#  Для пользователей Opera и любителей визуальных закладок у нас есть хорошая новость. Теперь при добав
# ...
#  правую кнопку мыши и настройте нужный вам интервал обновления.
# Любители визуальных закладок Яндекса
# targets: [('yandex', 0.9909844398498535)]
# predict: [('yandex', 0.9909844398498535), ('i_am_advertising', 0.9539413452148438), ('video_conferencing', 0.9237015843391418), ('google', 0.908289909362793), ('desktop_environment', 0.8984371423721313), ('hi', 0.8674866557121277), ('epam_systems', 0.8343629240989685), ('nanosoft', 0.8295309543609619), ('erp', 0.8262687921524048), ('saas', 0.7831814289093018), ('browsers', 0.7730265259742737), ('crowdsourcing', 0.7726432681083679), ('crm', 0.76032954454422), ('itsumma', 0.7536813616752625), ('history', 0.749879777431488), ('croc', 0.7470518350601196), ('dell_technologies', 0.7074265480041504), ('hflabs', 0.6657879948616028), ('kelnik', 0.6631227731704712), ('otus', 0.655450701713562)]
# id: 310
# dcg: 1.0
# ndcg: 1.0
# text:
#  Несмотря на то, что с мигренями сталкивается чуть ли не каждый из нас, а сами головные боли выводят
# ...
#  с помощью более масштабных исследований на более разнообразных выборках и в более длительные сроки.
# targets: [('brain', 0.9564120769500732)]
# predict: [('brain', 0.9564120769500732), ('i_am_advertising', 0.9129219651222229), ('desktop_environment', 0.9099959135055542), ('google', 0.870303213596344), ('artificial_intelligence', 0.8224015831947327), ('kelnik', 0.7816810607910156), ('epam_systems', 0.7759074568748474), ('itsumma', 0.7672802805900574), ('timeweb', 0.7460470199584961), ('paysto', 0.7259284257888794), ('crm', 0.7131354212760925), ('hi', 0.7016800045967102), ('history', 0.6689169406890869), ('it_testing', 0.6585337519645691), ('agile', 0.6444629430770874), ('design', 0.6435151696205139), ('erp', 0.6419315934181213), ('crowdsourcing', 0.6379884481430054), ('lifehacks', 0.631959080696106), ('infographics', 0.6171496510505676)]
# id: 453
# dcg: 1.0
# ndcg: 1.0
# text:
#  В концепте телефона Edge, придуманного дизайнером Крисом Оуэнсом, не уделено никакого внимания начин
# ...
#  полюбоваться стеклянным слайдером, который Оуэнс назвал «новым направлением в дизайне».
# via Gizmodo
# targets: [('design', 0.9468241333961487)]
# predict: [('design', 0.9468241333961487), ('php', 0.9171770811080933), ('closet', 0.8962079882621765), ('yii', 0.8958834409713745), ('html5', 0.8887526988983154), ('DIY', 0.8831576108932495), ('i_am_advertising', 0.8633109927177429), ('webdev', 0.859440267086029), ('usabilitylab', 0.825197160243988), ('ecommerce_development', 0.7707236409187317), ('geo', 0.7697954177856445), ('analysis_design', 0.7634701132774353), ('javascript', 0.762580156326294), ('uprock', 0.7548072338104248), ('droider', 0.7469545602798462), ('geo_systems', 0.7314184904098511), ('google', 0.7310279607772827), ('vk_api', 0.6869005560874939), ('crm', 0.678051769733429), ('paysto', 0.6735284328460693)]
# id: 436
# dcg: 1.0
# ndcg: 1.0
# text:
#  У меня, как у web-программиста, иногда возникает острая необходимость внести какие-то изменения в ко
# ...
# рограммы на Zenithink ZT-180, 10' — habrastorage.org/storage/203d9fc1/4f0c23e5/686256a8/dbed9e66.png
# targets: [('android_dev', 0.9909153580665588)]
# predict: [('android_dev', 0.9909153580665588), ('browser_extensions', 0.9399706125259399), ('i_am_advertising', 0.8823792934417725), ('browsers', 0.8795096278190613), ('facebook_api', 0.8638379573822021), ('google', 0.8505526781082153), ('css', 0.8351455926895142), ('closet', 0.8139421343803406), ('kelnik', 0.8077094554901123), ('desktop_environment', 0.7654210925102234), ('open_source', 0.7585142850875854), ('usabilitylab', 0.7460024952888489), ('hi', 0.7342476844787598), ('nanosoft', 0.6920070052146912), ('firefox', 0.6905161142349243), ('code_wtf', 0.6278405785560608), ('webdev', 0.625535249710083), ('win_dev', 0.6251813173294067), ('timeweb', 0.6177464127540588), ('video_conferencing', 0.6148688793182373)]

# %% [markdown]
# While the models is great on most popular labels.

# %% [markdown]
# I think next steps are:
# - using ranking losses in training
# - using better embeddings
# - generating more balanced dataset
